# %%
from data.table.Table import Table

from training import TrainingExample

from dcs.aggregation.Avg import Avg
from dcs.aggregation.Count import Count
from dcs.aggregation.Max import Max
from dcs.aggregation.Min import Min
from dcs.aggregation.Sum import Sum
from dcs.arithmetic.Add import Add

from dcs.comparitor.GreaterThan import GreaterThan
from dcs.comparitor.GreaterThanEq import GreaterThanEq
from dcs.comparitor.LessThan import LessThan
from dcs.comparitor.LessThanEq import LessThanEq
from dcs.comparitor.NEq import NEq
from dcs.comparitor.Eq import Eq


from dcs.base.Atom import Atom
from dcs.base.Entity import Entity
from dcs.base.Property import Property
from dcs.base.Unary import Unary
from dcs.base.NormalisationAtom import NormalisationAtom
from dcs.base.Record import Record
from dcs.base.DateAtom import DateAtom
from dcs.base.ComparableAtom import ComparableAtom
from dcs.comparitor.GreaterThan import GreaterThan
from dcs.relation.Chain import Chain
from dcs.relation.Intersection import Intersection
from dcs.relation.Join import Join
from dcs.relation.Negate import Negate
from dcs.relation.Reverse import Reverse
from dcs.relation.Union import Union
from dcs.superlative.ArgMax import ArgMax
from dcs.superlative.ArgMin import ArgMin

from parser.TokenSpan import TokenSpan
from parser.GroundingStep import get_table_properties
from parser.GroundingStep import get_question_properties

from util.dateutils import *
from util.numberutils import *
# Out:
# Loading spacy
# Done

# %%
def check_produces(p):
    v = p.vals()
    return v is not None and len(v) > 0

def check_not_identical(p1,p2):
    return p1 != p2

def check_not_same_productions(p1,p2):
    return p1.vals() != p2.vals()

def check_same_ret_type(p1,p2):
    return p1.get_types() == p2.get_types()

def check_reverse(b):
    return not isinstance(b,Reverse)

def check_k_type(b1,b2):
    return b1.chain(b2)

def check_cmp(b,a):
    return any([t in a.get_types() for t in [Atom, DateAtom]]) and set([type(v.v) for v in b.vals()]) == set([type(v) for v in a.vals()])
    

def check_single(u):
    return len(u.vals())==1
training_ex = TrainingExample("Greece last held its Summer Olympics since 2004?",None,None)
table = Table("test.tsv")


u1, b1 = get_table_properties(table)
u2, b2 = get_question_properties(training_ex)

u = set()
u.update(u1)
u.update(u2)

b = set()
b.update(b1)
b.update(b2)




def cross_product(list1,list2):
    return [(a,b) for a in list1 for b in list2]



def act_union(bits):   
    if not check_produces(bits[0]) or not check_produces(bits[1]):
        return []
    
    if not check_not_identical(bits[0],bits[1]):
        return []
    
    if not check_same_ret_type(bits[0],bits[1]):
        return []
    
    q = Union(bits[0],bits[1])
    
    if check_produces(q):
        return [q]
    else:
        return []
    
    
    

def act_intersection(bits):
    if not check_produces(bits[0]) or not check_produces(bits[1]):
        return []
    
    if not check_not_identical(bits[0],bits[1]):
        return []
    
    if not check_same_ret_type(bits[0],bits[1]):
        return []
        
    q = Intersection(bits[0],bits[1])
    if check_produces(q):
        return [q]
    else:
        return []




def act_join(bits):
    return [Join(bits[0],bits[1])]

def act_agg(u):
    if isinstance(u,Atom):
        return [Min(u), Max(u), Count(u), Avg(u), Sum(u)]
    return [Count(u)]
        
def act_sup(bits):
    u = bits[0]
    b = bits[1]
    
    if not check_produces(b):
        return []
    
    if not check_produces(u):
        return []
    
    if b.compatible(u):
        return [ArgMin(u,b), ArgMax(u,b)]
    return []

def act_reverse(b):
    if not check_produces(b):
        return []
    
    if not check_reverse(b):
        return []
    
    return [Reverse(b)]

def act_chain(bs):
    b1 = bs[0]
    b2 = bs[1]
    
    if not check_produces(b1):
        return []
    
    if not check_produces(b2):
        return []
    
    if not check_k_type(b1,b2):
        return []
    
    return [Chain(b1,b2)]
    
def act_cmp(ba):
    b = ba[0]
    a = ba[1]
    
    if not check_single(a):
        return []
    
    if not check_cmp(b,a):
        return []
    
    
    return [Join(b, GreaterThan(a)),
            Join(b, GreaterThanEq(a)),
            Join(b, LessThan(a)),
            Join(b, LessThanEq(a)),
            Join(b, Eq(a)),
            Join(b, NEq(a)),
           ]
       


def transition(u,b,v_prods):
    atoms = [au for au in u if isinstance(au,Atom)]
    
    ab_actions = [(act_cmp, cross_product(b,atoms)) ]
    
    u_actions = [( act_union , cross_product(u,u) ),
             ( act_intersection, cross_product(u,u) ),
             ( act_agg, u )
            ]

    bu_actions = [( act_join , cross_product(b,u) ),
                  ( act_sup, cross_product(u,b) )
                 ]

    b_actions = [ ( act_reverse, b),
                  ( act_chain, cross_product(b,b)) 
                ]


    print("Starting with " + str(len(u)) + " unaries")
    print("Starting with " + str(len(b)) + " binaries")
    
    u_next = set()
    b_next = set()

    for action,data in ab_actions:
        for datum in data:
            for a in action(datum):
                if check_produces(a):
                    u_next.add((datum,a))
    
    for action,data in u_actions:
        for datum in data:
            for a in action(datum):
                if check_produces(a):
                    u_next.add((datum,a))
    
    for action,data in bu_actions:
        for datum in data:
            for a in action(datum):
                if check_produces(a):
                    u_next.add((datum,a))

    

    for action,data in b_actions:
        for datum in data:
            for a in action(datum):
                if check_produces(a):
                    b_next.add((datum,a))
           
    u_ret = set()
    b_ret = set()
    
    u_ret.update(u)
    b_ret.update(b)
    
    for data,a in u_next:
         u_ret.add(a)
    for data,a in b_next:
         b_ret.add(a)
               
    for a in u_ret:
         print(a)
            
    for a in b_ret:
         print(a)
    
    return u_ret,b_ret
        

u,b = transition(u,b,None)
u,b = transition(u,b,None)
# Out:
# Starting with 5 unaries
# Starting with 11 binaries
# [JOIN: [PROPERTY: $number] x [ATOM:2004.0]]
# [JOIN: [PROPERTY: $date$year] x [GTE [ATOM:2004.0]]]
# [COUNT: [NORMALIZE 2004]]
# [ARGMAX: [NORMALIZE 2004] [PROPERTY: $number]]
# [UNARY: $records]
# [JOIN: [PROPERTY: $date$year] x [NEQ [ATOM:2004.0]]]
# [JOIN: [PROPERTY: $index] x [LTE [ATOM:2004.0]]]
# [COUNT: [UNARY: $records]]
# [ARGMAX: [UNARY: $records] [PROPERTY: $index]]
# [JOIN: [PROPERTY: $index] x [LT [ATOM:2004.0]]]
# [JOIN: [PROPERTY: $date$year] x [ATOM:2004.0]]
# [JOIN: [PROPERTY: $date$year] x [EQ [ATOM:2004.0]]]
# [MAX: [ATOM:2004.0]]
# [JOIN: [PROPERTY: $number] x [LTE [ATOM:2004.0]]]
# [ARGMIN: [DATE Y: 2004 M: None D:None]  [PROPERTY: $date$year]]
# [JOIN: [PROPERTY: $number] x [EQ [ATOM:2004.0]]]
# [JOIN: [PROPERTY: $next] x [UNARY: $records]]
# [JOIN: [PROPERTY: Year] x [NORMALIZE 2004]]
# [JOIN: [PROPERTY: $date$year] x [GT [ATOM:2004.0]]]
# [JOIN: [PROPERTY: $number] x [GTE [ATOM:2004.0]]]
# [JOIN: [PROPERTY: $index] x [NEQ [ATOM:2004.0]]]
# [COUNT: [ATOM:2004.0]]
# [JOIN: [PROPERTY: $number] x [LT [ATOM:2004.0]]]
# [NORMALIZE 2004]
# [DATE Y: 2004 M: None D:None]
# [JOIN: [PROPERTY: $date$year] x [LTE [ATOM:2004.0]]]
# [ARGMIN: [NORMALIZE 2004] [PROPERTY: $number]]
# [ATOM:2004.0]
# [JOIN: [PROPERTY: Country] x [ENTITY:Greece]]
# [AVG: [ATOM:2004.0]]
# [JOIN: [PROPERTY: $number] x [NEQ [ATOM:2004.0]]]
# [ARGMAX: [DATE Y: 2004 M: None D:None]  [PROPERTY: $date$year]]
# [SUM: [ATOM:2004.0]]
# [ARGMIN: [UNARY: $records] [PROPERTY: $index]]
# [JOIN: [PROPERTY: $date] x [DATE Y: 2004 M: None D:None] ]
# [MIN: [ATOM:2004.0]]
# [ENTITY:Greece]
# [COUNT: [ENTITY:Greece]]
# [JOIN: [PROPERTY: $number] x [GT [ATOM:2004.0]]]
# [JOIN: [PROPERTY: $date$year] x [LT [ATOM:2004.0]]]
# [COUNT: [DATE Y: 2004 M: None D:None] ]
# R[[PROPERTY: $date]]
# [CHAIN: [PROPERTY: $next] x [PROPERTY: City]]
# [CHAIN: [PROPERTY: $date] x [PROPERTY: $date$year]]
# [PROPERTY: Country]
# [PROPERTY: $next]
# [CHAIN: [PROPERTY: Nations] x [PROPERTY: $number]]
# R[[PROPERTY: Year]]
# [PROPERTY: $date$day]
# [PROPERTY: $index]
# [CHAIN: [PROPERTY: Year] x [PROPERTY: $date]]
# [PROPERTY: Nations]
# R[[PROPERTY: $date$year]]
# [CHAIN: [PROPERTY: $next] x [PROPERTY: Year]]
# [PROPERTY: $number]
# R[[PROPERTY: City]]
# [PROPERTY: City]
# [PROPERTY: $date$month]
# R[[PROPERTY: $number]]
# [CHAIN: [PROPERTY: $next] x [PROPERTY: $next]]
# [PROPERTY: $date$year]
# [CHAIN: [PROPERTY: Year] x [PROPERTY: $number]]
# [CHAIN: [PROPERTY: $next] x [PROPERTY: Country]]
# R[[PROPERTY: Nations]]
# R[[PROPERTY: $index]]
# [CHAIN: [PROPERTY: Nations] x [PROPERTY: $date]]
# [CHAIN: [PROPERTY: $next] x [PROPERTY: $index]]
# [PROPERTY: Year]
# [CHAIN: [PROPERTY: $next] x [PROPERTY: Nations]]
# R[[PROPERTY: Country]]
# R[[PROPERTY: $next]]
# [PROPERTY: $date]
# Starting with 41 unaries
# Starting with 31 binaries
# [JOIN: [CHAIN: [PROPERTY: Year] x [PROPERTY: $date]] x [JOIN: [PROPERTY: $date$year] x [ATOM:2004.0]]]
# [INTERSECTION: [ARGMIN: [DATE Y: 2004 M: None D:None]  [PROPERTY: $date$year]] ^ [DATE Y: 2004 M: None D:None] ]
# [JOIN: [PROPERTY: Nations] x [JOIN: [PROPERTY: $number] x [LTE [ATOM:2004.0]]]]
# [INTERSECTION: [ARGMIN: [DATE Y: 2004 M: None D:None]  [PROPERTY: $date$year]] ^ [JOIN: [PROPERTY: $date$year] x [EQ [ATOM:2004.0]]]]
# [JOIN: [CHAIN: [PROPERTY: Year] x [PROPERTY: $date]] x [JOIN: [PROPERTY: $date$year] x [LTE [ATOM:2004.0]]]]
# [INTERSECTION: [ARGMIN: [DATE Y: 2004 M: None D:None]  [PROPERTY: $date$year]] ^ [JOIN: [PROPERTY: $date$year] x [ATOM:2004.0]]]
# [JOIN: [CHAIN: [PROPERTY: Year] x [PROPERTY: $date]] x [ARGMIN: [DATE Y: 2004 M: None D:None]  [PROPERTY: $date$year]]]
# [INTERSECTION: [ARGMIN: [DATE Y: 2004 M: None D:None]  [PROPERTY: $date$year]] ^ [JOIN: [PROPERTY: $date$year] x [GTE [ATOM:2004.0]]]]
# [INTERSECTION: [JOIN: [PROPERTY: $number] x [LTE [ATOM:2004.0]]] ^ [JOIN: [PROPERTY: $date] x [DATE Y: 2004 M: None D:None] ]]
# [JOIN: [CHAIN: [PROPERTY: Year] x [PROPERTY: $date]] x [JOIN: [PROPERTY: $date$year] x [NEQ [ATOM:2004.0]]]]
# [JOIN: [PROPERTY: $index] x [COUNT: [ENTITY:Greece]]]
# [INTERSECTION: [JOIN: [PROPERTY: $number] x [LTE [ATOM:2004.0]]] ^ [JOIN: [PROPERTY: $number] x [NEQ [ATOM:2004.0]]]]
# [JOIN: [CHAIN: [PROPERTY: Year] x [PROPERTY: $date]] x [JOIN: [PROPERTY: $date$year] x [GTE [ATOM:2004.0]]]]
# [INTERSECTION: [JOIN: [PROPERTY: $number] x [LTE [ATOM:2004.0]]] ^ [ARGMIN: [NORMALIZE 2004] [PROPERTY: $number]]]
# [INTERSECTION: [JOIN: [PROPERTY: $number] x [LTE [ATOM:2004.0]]] ^ [NORMALIZE 2004]]
# [JOIN: [PROPERTY: $index] x [COUNT: [DATE Y: 2004 M: None D:None] ]]
# [JOIN: [CHAIN: [PROPERTY: Year] x [PROPERTY: $date]] x [DATE Y: 2004 M: None D:None] ]
# [INTERSECTION: [JOIN: [PROPERTY: $number] x [LTE [ATOM:2004.0]]] ^ [JOIN: [PROPERTY: $number] x [LT [ATOM:2004.0]]]]
# [JOIN: R[[PROPERTY: Year]] x [JOIN: [PROPERTY: $index] x [NEQ [ATOM:2004.0]]]]
# [INTERSECTION: [JOIN: [PROPERTY: $number] x [LTE [ATOM:2004.0]]] ^ [JOIN: [PROPERTY: $number] x [GTE [ATOM:2004.0]]]]
# [INTERSECTION: [JOIN: [PROPERTY: $number] x [LTE [ATOM:2004.0]]] ^ [JOIN: [PROPERTY: $number] x [EQ [ATOM:2004.0]]]]
# [JOIN: [PROPERTY: $index] x [COUNT: [NORMALIZE 2004]]]
# [INTERSECTION: [JOIN: [PROPERTY: $number] x [LTE [ATOM:2004.0]]] ^ [ARGMAX: [NORMALIZE 2004] [PROPERTY: $number]]]
# [JOIN: R[[PROPERTY: Year]] x [JOIN: [PROPERTY: $index] x [LT [ATOM:2004.0]]]]
# [INTERSECTION: [JOIN: [PROPERTY: $number] x [LTE [ATOM:2004.0]]] ^ [JOIN: [PROPERTY: $number] x [ATOM:2004.0]]]
# [JOIN: [CHAIN: [PROPERTY: Year] x [PROPERTY: $date]] x [JOIN: [PROPERTY: $date$year] x [EQ [ATOM:2004.0]]]]
# [INTERSECTION: [MAX: [ATOM:2004.0]] ^ [MIN: [ATOM:2004.0]]]
# [JOIN: R[[PROPERTY: Year]] x [ARGMIN: [UNARY: $records] [PROPERTY: $index]]]
# [INTERSECTION: [MAX: [ATOM:2004.0]] ^ [AVG: [ATOM:2004.0]]]
# [JOIN: R[[PROPERTY: Year]] x [JOIN: [PROPERTY: $next] x [UNARY: $records]]]
# [JOIN: [PROPERTY: $index] x [COUNT: [ATOM:2004.0]]]
# [INTERSECTION: [MAX: [ATOM:2004.0]] ^ [SUM: [ATOM:2004.0]]]
# [INTERSECTION: [MAX: [ATOM:2004.0]] ^ [ATOM:2004.0]]
# [JOIN: [CHAIN: [PROPERTY: Year] x [PROPERTY: $date]] x [ARGMAX: [DATE Y: 2004 M: None D:None]  [PROPERTY: $date$year]]]
# [INTERSECTION: [JOIN: [PROPERTY: $date$year] x [EQ [ATOM:2004.0]]] ^ [ARGMAX: [DATE Y: 2004 M: None D:None]  [PROPERTY: $date$year]]]
# [JOIN: R[[PROPERTY: Year]] x [JOIN: [PROPERTY: $index] x [LTE [ATOM:2004.0]]]]
# [JOIN: R[[PROPERTY: Year]] x [UNARY: $records]]
# [INTERSECTION: [JOIN: [PROPERTY: $date$year] x [EQ [ATOM:2004.0]]] ^ [JOIN: [PROPERTY: $date$year] x [LTE [ATOM:2004.0]]]]
# [JOIN: R[[PROPERTY: Year]] x [JOIN: [PROPERTY: Year] x [NORMALIZE 2004]]]
# [INTERSECTION: [JOIN: [PROPERTY: $date$year] x [EQ [ATOM:2004.0]]] ^ [DATE Y: 2004 M: None D:None] ]
# [INTERSECTION: [JOIN: [PROPERTY: $date$year] x [EQ [ATOM:2004.0]]] ^ [ARGMIN: [DATE Y: 2004 M: None D:None]  [PROPERTY: $date$year]]]
# [NORMALIZE 2004]
# [DATE Y: 2004 M: None D:None]
# [JOIN: [PROPERTY: $next] x [ARGMAX: [UNARY: $records] [PROPERTY: $index]]]
# [JOIN: [PROPERTY: Country] x [ENTITY:Greece]]
# [INTERSECTION: [JOIN: [PROPERTY: $date$year] x [EQ [ATOM:2004.0]]] ^ [JOIN: [PROPERTY: $date$year] x [ATOM:2004.0]]]
# [INTERSECTION: [JOIN: [PROPERTY: $date$year] x [EQ [ATOM:2004.0]]] ^ [JOIN: [PROPERTY: $date$year] x [GTE [ATOM:2004.0]]]]
# [JOIN: [PROPERTY: $next] x [JOIN: [PROPERTY: Year] x [NORMALIZE 2004]]]
# [JOIN: [CHAIN: [PROPERTY: $date] x [PROPERTY: $date$year]] x [MIN: [ATOM:2004.0]]]
# [INTERSECTION: [JOIN: [PROPERTY: $date$year] x [ATOM:2004.0]] ^ [ARGMAX: [DATE Y: 2004 M: None D:None]  [PROPERTY: $date$year]]]
# [JOIN: [PROPERTY: $next] x [JOIN: [PROPERTY: $index] x [NEQ [ATOM:2004.0]]]]
# [INTERSECTION: [JOIN: [PROPERTY: $date$year] x [ATOM:2004.0]] ^ [JOIN: [PROPERTY: $date$year] x [LTE [ATOM:2004.0]]]]
# [JOIN: [PROPERTY: $next] x [UNARY: $records]]
# [INTERSECTION: [JOIN: [PROPERTY: $date$year] x [ATOM:2004.0]] ^ [DATE Y: 2004 M: None D:None] ]
# [JOIN: R[[PROPERTY: Year]] x [JOIN: [PROPERTY: Country] x [ENTITY:Greece]]]
# [INTERSECTION: [JOIN: [PROPERTY: $date$year] x [ATOM:2004.0]] ^ [ARGMIN: [DATE Y: 2004 M: None D:None]  [PROPERTY: $date$year]]]
# [JOIN: R[[PROPERTY: $date]] x [JOIN: [PROPERTY: $date] x [DATE Y: 2004 M: None D:None] ]]
# [INTERSECTION: [JOIN: [PROPERTY: $date$year] x [ATOM:2004.0]] ^ [JOIN: [PROPERTY: $date$year] x [EQ [ATOM:2004.0]]]]
# [JOIN: [CHAIN: [PROPERTY: $date] x [PROPERTY: $date$year]] x [MAX: [ATOM:2004.0]]]
# [INTERSECTION: [JOIN: [PROPERTY: $date$year] x [ATOM:2004.0]] ^ [JOIN: [PROPERTY: $date$year] x [GTE [ATOM:2004.0]]]]
# [INTERSECTION: [JOIN: [PROPERTY: $index] x [LT [ATOM:2004.0]]] ^ [ARGMIN: [UNARY: $records] [PROPERTY: $index]]]
# [JOIN: [PROPERTY: $next] x [JOIN: [PROPERTY: $next] x [UNARY: $records]]]
# [INTERSECTION: [JOIN: [PROPERTY: $index] x [LT [ATOM:2004.0]]] ^ [JOIN: [PROPERTY: Country] x [ENTITY:Greece]]]
# [JOIN: R[[PROPERTY: $date]] x [ARGMIN: [NORMALIZE 2004] [PROPERTY: $number]]]
# [INTERSECTION: [JOIN: [PROPERTY: $index] x [LT [ATOM:2004.0]]] ^ [JOIN: [PROPERTY: $index] x [NEQ [ATOM:2004.0]]]]
# [JOIN: R[[PROPERTY: $date]] x [NORMALIZE 2004]]
# [INTERSECTION: [JOIN: [PROPERTY: $index] x [LT [ATOM:2004.0]]] ^ [JOIN: [PROPERTY: Year] x [NORMALIZE 2004]]]
# [JOIN: R[[PROPERTY: $date]] x [JOIN: [PROPERTY: $number] x [LT [ATOM:2004.0]]]]
# [INTERSECTION: [JOIN: [PROPERTY: $index] x [LT [ATOM:2004.0]]] ^ [JOIN: [PROPERTY: $next] x [UNARY: $records]]]
# [JOIN: [CHAIN: [PROPERTY: $date] x [PROPERTY: $date$year]] x [AVG: [ATOM:2004.0]]]
# [INTERSECTION: [JOIN: [PROPERTY: $index] x [LT [ATOM:2004.0]]] ^ [ARGMAX: [UNARY: $records] [PROPERTY: $index]]]
# [JOIN: R[[PROPERTY: $date]] x [JOIN: [PROPERTY: $number] x [LTE [ATOM:2004.0]]]]
# [JOIN: R[[PROPERTY: $date]] x [JOIN: [PROPERTY: $number] x [NEQ [ATOM:2004.0]]]]
# [INTERSECTION: [JOIN: [PROPERTY: $index] x [LT [ATOM:2004.0]]] ^ [JOIN: [PROPERTY: $index] x [LTE [ATOM:2004.0]]]]
# [JOIN: R[[PROPERTY: $date]] x [ARGMAX: [NORMALIZE 2004] [PROPERTY: $number]]]
# [INTERSECTION: [JOIN: [PROPERTY: $index] x [LT [ATOM:2004.0]]] ^ [UNARY: $records]]
# [JOIN: [CHAIN: [PROPERTY: $date] x [PROPERTY: $date$year]] x [SUM: [ATOM:2004.0]]]
# [JOIN: [PROPERTY: $next] x [JOIN: [PROPERTY: $index] x [LTE [ATOM:2004.0]]]]
# [INTERSECTION: [ARGMAX: [UNARY: $records] [PROPERTY: $index]] ^ [JOIN: [PROPERTY: $index] x [NEQ [ATOM:2004.0]]]]
# [JOIN: R[[PROPERTY: $date]] x [JOIN: [PROPERTY: $number] x [GT [ATOM:2004.0]]]]
# [INTERSECTION: [ARGMAX: [UNARY: $records] [PROPERTY: $index]] ^ [JOIN: [PROPERTY: $index] x [LT [ATOM:2004.0]]]]
# [JOIN: R[[PROPERTY: $date]] x [JOIN: [PROPERTY: $number] x [GTE [ATOM:2004.0]]]]
# [INTERSECTION: [ARGMAX: [UNARY: $records] [PROPERTY: $index]] ^ [JOIN: [PROPERTY: $index] x [LTE [ATOM:2004.0]]]]
# [JOIN: [PROPERTY: $next] x [JOIN: [PROPERTY: Country] x [ENTITY:Greece]]]
# [INTERSECTION: [ARGMAX: [UNARY: $records] [PROPERTY: $index]] ^ [UNARY: $records]]
# [JOIN: [CHAIN: [PROPERTY: $date] x [PROPERTY: $date$year]] x [ATOM:2004.0]]
# [INTERSECTION: [JOIN: [PROPERTY: $index] x [LTE [ATOM:2004.0]]] ^ [ARGMIN: [UNARY: $records] [PROPERTY: $index]]]
# [JOIN: R[[PROPERTY: $date]] x [JOIN: [PROPERTY: $number] x [EQ [ATOM:2004.0]]]]
# [INTERSECTION: [JOIN: [PROPERTY: $index] x [LTE [ATOM:2004.0]]] ^ [JOIN: [PROPERTY: Country] x [ENTITY:Greece]]]
# [INTERSECTION: [JOIN: [PROPERTY: $index] x [LTE [ATOM:2004.0]]] ^ [JOIN: [PROPERTY: $index] x [NEQ [ATOM:2004.0]]]]
# [JOIN: [PROPERTY: $next] x [JOIN: [PROPERTY: $index] x [LT [ATOM:2004.0]]]]
# [INTERSECTION: [JOIN: [PROPERTY: $index] x [LTE [ATOM:2004.0]]] ^ [JOIN: [PROPERTY: Year] x [NORMALIZE 2004]]]
# [JOIN: [CHAIN: [PROPERTY: Year] x [PROPERTY: $date]] x [JOIN: [PROPERTY: $date$year] x [GT [ATOM:2004.0]]]]
# [JOIN: R[[PROPERTY: $date]] x [JOIN: [PROPERTY: $number] x [ATOM:2004.0]]]
# [INTERSECTION: [JOIN: [PROPERTY: $index] x [LTE [ATOM:2004.0]]] ^ [JOIN: [PROPERTY: $next] x [UNARY: $records]]]
# [INTERSECTION: [JOIN: [PROPERTY: $index] x [LTE [ATOM:2004.0]]] ^ [JOIN: [PROPERTY: $index] x [LT [ATOM:2004.0]]]]
# [INTERSECTION: [JOIN: [PROPERTY: $index] x [LTE [ATOM:2004.0]]] ^ [ARGMAX: [UNARY: $records] [PROPERTY: $index]]]
# [COUNT: [COUNT: [DATE Y: 2004 M: None D:None] ]]
# [COUNT: [JOIN: [PROPERTY: $date$year] x [LT [ATOM:2004.0]]]]
# [INTERSECTION: [JOIN: [PROPERTY: $index] x [LTE [ATOM:2004.0]]] ^ [UNARY: $records]]
# [COUNT: [JOIN: [PROPERTY: $number] x [GT [ATOM:2004.0]]]]
# [INTERSECTION: [JOIN: [PROPERTY: $date$year] x [NEQ [ATOM:2004.0]]] ^ [JOIN: [PROPERTY: $date$year] x [LT [ATOM:2004.0]]]]
# [INTERSECTION: [JOIN: [PROPERTY: $date$year] x [NEQ [ATOM:2004.0]]] ^ [JOIN: [PROPERTY: $date$year] x [LTE [ATOM:2004.0]]]]
# [INTERSECTION: [ARGMIN: [DATE Y: 2004 M: None D:None]  [PROPERTY: $date$year]] ^ [JOIN: [PROPERTY: $date$year] x [LTE [ATOM:2004.0]]]]
# [COUNT: [COUNT: [ENTITY:Greece]]]
# [COUNT: [ENTITY:Greece]]
# [INTERSECTION: [JOIN: [PROPERTY: $date$year] x [NEQ [ATOM:2004.0]]] ^ [JOIN: [PROPERTY: $date$year] x [GT [ATOM:2004.0]]]]
# [INTERSECTION: [JOIN: [PROPERTY: $date$year] x [NEQ [ATOM:2004.0]]] ^ [JOIN: [PROPERTY: $date$year] x [GTE [ATOM:2004.0]]]]
# [COUNT: [MIN: [ATOM:2004.0]]]
# [COUNT: [JOIN: [PROPERTY: $date] x [DATE Y: 2004 M: None D:None] ]]
# [COUNT: [ARGMIN: [UNARY: $records] [PROPERTY: $index]]]
# [COUNT: [SUM: [ATOM:2004.0]]]
# [INTERSECTION: [UNARY: $records] ^ [ARGMIN: [UNARY: $records] [PROPERTY: $index]]]
# [COUNT: [ARGMAX: [DATE Y: 2004 M: None D:None]  [PROPERTY: $date$year]]]
# [INTERSECTION: [UNARY: $records] ^ [JOIN: [PROPERTY: Country] x [ENTITY:Greece]]]
# [INTERSECTION: [UNARY: $records] ^ [JOIN: [PROPERTY: $index] x [NEQ [ATOM:2004.0]]]]
# [COUNT: [COUNT: [ATOM:2004.0]]]
# [COUNT: [JOIN: [PROPERTY: $number] x [NEQ [ATOM:2004.0]]]]
# [COUNT: [AVG: [ATOM:2004.0]]]
# [INTERSECTION: [UNARY: $records] ^ [JOIN: [PROPERTY: Year] x [NORMALIZE 2004]]]
# [INTERSECTION: [ARGMAX: [NORMALIZE 2004] [PROPERTY: $number]] ^ [JOIN: [PROPERTY: $number] x [GTE [ATOM:2004.0]]]]
# [COUNT: [JOIN: [PROPERTY: Country] x [ENTITY:Greece]]]
# [INTERSECTION: [UNARY: $records] ^ [JOIN: [PROPERTY: $next] x [UNARY: $records]]]
# [INTERSECTION: [UNARY: $records] ^ [JOIN: [PROPERTY: $index] x [LT [ATOM:2004.0]]]]
# [SUM: [ATOM:2004.0]]
# [AVG: [ATOM:2004.0]]
# [COUNT: [ATOM:2004.0]]
# [INTERSECTION: [UNARY: $records] ^ [ARGMAX: [UNARY: $records] [PROPERTY: $index]]]
# [MAX: [ATOM:2004.0]]
# [MIN: [ATOM:2004.0]]
# [COUNT: [ARGMIN: [NORMALIZE 2004] [PROPERTY: $number]]]
# [INTERSECTION: [UNARY: $records] ^ [JOIN: [PROPERTY: $index] x [LTE [ATOM:2004.0]]]]
# [INTERSECTION: [ARGMAX: [NORMALIZE 2004] [PROPERTY: $number]] ^ [JOIN: [PROPERTY: $date] x [DATE Y: 2004 M: None D:None] ]]
# [COUNT: [JOIN: [PROPERTY: $date$year] x [LTE [ATOM:2004.0]]]]
# [INTERSECTION: [ARGMAX: [NORMALIZE 2004] [PROPERTY: $number]] ^ [ARGMIN: [NORMALIZE 2004] [PROPERTY: $number]]]
# [COUNT: [DATE Y: 2004 M: None D:None] ]
# [COUNT: [NORMALIZE 2004]]
# [INTERSECTION: [ARGMAX: [NORMALIZE 2004] [PROPERTY: $number]] ^ [NORMALIZE 2004]]
# [COUNT: [JOIN: [PROPERTY: $number] x [LT [ATOM:2004.0]]]]
# [INTERSECTION: [ARGMAX: [NORMALIZE 2004] [PROPERTY: $number]] ^ [JOIN: [PROPERTY: $number] x [EQ [ATOM:2004.0]]]]
# [INTERSECTION: [JOIN: [PROPERTY: $number] x [EQ [ATOM:2004.0]]] ^ [ARGMAX: [NORMALIZE 2004] [PROPERTY: $number]]]
# [INTERSECTION: [COUNT: [NORMALIZE 2004]] ^ [COUNT: [ENTITY:Greece]]]
# [UNION: [JOIN: [PROPERTY: $date$year] x [GTE [ATOM:2004.0]]] ^ [JOIN: [PROPERTY: $date$year] x [GT [ATOM:2004.0]]]]
# [UNION: [JOIN: [PROPERTY: $number] x [ATOM:2004.0]] ^ [JOIN: [PROPERTY: $date] x [DATE Y: 2004 M: None D:None] ]]
# [UNION: [JOIN: [PROPERTY: $number] x [ATOM:2004.0]] ^ [ARGMIN: [NORMALIZE 2004] [PROPERTY: $number]]]
# [UNION: [JOIN: [PROPERTY: $date$year] x [GTE [ATOM:2004.0]]] ^ [DATE Y: 2004 M: None D:None] ]
# [UNION: [JOIN: [PROPERTY: $date$year] x [GTE [ATOM:2004.0]]] ^ [ARGMIN: [DATE Y: 2004 M: None D:None]  [PROPERTY: $date$year]]]
# [UNION: [JOIN: [PROPERTY: $number] x [ATOM:2004.0]] ^ [ARGMAX: [NORMALIZE 2004] [PROPERTY: $number]]]
# [JOIN: [CHAIN: [PROPERTY: $next] x [PROPERTY: $index]] x [NEQ [ATOM:2004.0]]]
# [JOIN: [CHAIN: [PROPERTY: $next] x [PROPERTY: $index]] x [LTE [ATOM:2004.0]]]
# [INTERSECTION: [ARGMAX: [NORMALIZE 2004] [PROPERTY: $number]] ^ [JOIN: [PROPERTY: $number] x [LTE [ATOM:2004.0]]]]
# [UNION: [JOIN: [PROPERTY: $date$year] x [GTE [ATOM:2004.0]]] ^ [JOIN: [PROPERTY: $date$year] x [ATOM:2004.0]]]
# [UNION: [JOIN: [PROPERTY: $number] x [ATOM:2004.0]] ^ [JOIN: [PROPERTY: $number] x [EQ [ATOM:2004.0]]]]
# [UNION: [JOIN: [PROPERTY: $date$year] x [GTE [ATOM:2004.0]]] ^ [JOIN: [PROPERTY: $date$year] x [EQ [ATOM:2004.0]]]]
# [UNION: [JOIN: [PROPERTY: $number] x [ATOM:2004.0]] ^ [NORMALIZE 2004]]
# [UNION: [JOIN: [PROPERTY: $date$year] x [GTE [ATOM:2004.0]]] ^ [JOIN: [PROPERTY: $date$year] x [NEQ [ATOM:2004.0]]]]
# [UNION: [JOIN: [PROPERTY: $index] x [LT [ATOM:2004.0]]] ^ [JOIN: [PROPERTY: $index] x [LTE [ATOM:2004.0]]]]
# [JOIN: [CHAIN: [PROPERTY: Year] x [PROPERTY: $number]] x [NEQ [ATOM:2004.0]]]
# [UNION: [JOIN: [PROPERTY: $number] x [ATOM:2004.0]] ^ [JOIN: [PROPERTY: $number] x [NEQ [ATOM:2004.0]]]]
# [UNION: [JOIN: [PROPERTY: $number] x [ATOM:2004.0]] ^ [JOIN: [PROPERTY: $number] x [LT [ATOM:2004.0]]]]
# [UNION: [JOIN: [PROPERTY: $number] x [ATOM:2004.0]] ^ [JOIN: [PROPERTY: $number] x [GT [ATOM:2004.0]]]]
# [JOIN: [CHAIN: [PROPERTY: $next] x [PROPERTY: $index]] x [LT [ATOM:2004.0]]]
# [UNION: [JOIN: [PROPERTY: $number] x [ATOM:2004.0]] ^ [JOIN: [PROPERTY: $number] x [LTE [ATOM:2004.0]]]]
# [UNION: [JOIN: [PROPERTY: $number] x [ATOM:2004.0]] ^ [JOIN: [PROPERTY: $number] x [GTE [ATOM:2004.0]]]]
# [JOIN: [CHAIN: [PROPERTY: $date] x [PROPERTY: $date$year]] x [NEQ [ATOM:2004.0]]]
# [INTERSECTION: [ARGMAX: [NORMALIZE 2004] [PROPERTY: $number]] ^ [JOIN: [PROPERTY: $number] x [ATOM:2004.0]]]
# [UNION: [JOIN: [PROPERTY: Year] x [NORMALIZE 2004]] ^ [JOIN: [PROPERTY: $next] x [UNARY: $records]]]
# [INTERSECTION: [COUNT: [NORMALIZE 2004]] ^ [COUNT: [DATE Y: 2004 M: None D:None] ]]
# [UNION: [ARGMIN: [DATE Y: 2004 M: None D:None]  [PROPERTY: $date$year]] ^ [JOIN: [PROPERTY: $date$year] x [LTE [ATOM:2004.0]]]]
# [INTERSECTION: [COUNT: [NORMALIZE 2004]] ^ [COUNT: [ATOM:2004.0]]]
# [UNION: [JOIN: [PROPERTY: Year] x [NORMALIZE 2004]] ^ [ARGMAX: [UNARY: $records] [PROPERTY: $index]]]
# [INTERSECTION: [JOIN: [PROPERTY: $date$year] x [GTE [ATOM:2004.0]]] ^ [ARGMAX: [DATE Y: 2004 M: None D:None]  [PROPERTY: $date$year]]]
# [INTERSECTION: [JOIN: [PROPERTY: $date$year] x [GTE [ATOM:2004.0]]] ^ [JOIN: [PROPERTY: $date$year] x [LTE [ATOM:2004.0]]]]
# [UNION: [JOIN: [PROPERTY: $date$year] x [GT [ATOM:2004.0]]] ^ [JOIN: [PROPERTY: $date$year] x [LTE [ATOM:2004.0]]]]
# [INTERSECTION: [JOIN: [PROPERTY: $date$year] x [GTE [ATOM:2004.0]]] ^ [DATE Y: 2004 M: None D:None] ]
# [JOIN: [PROPERTY: $number] x [GT [ATOM:2004.0]]]
# [UNION: [JOIN: [PROPERTY: Year] x [NORMALIZE 2004]] ^ [JOIN: [PROPERTY: $index] x [LTE [ATOM:2004.0]]]]
# [INTERSECTION: [JOIN: [PROPERTY: $date$year] x [GTE [ATOM:2004.0]]] ^ [JOIN: [PROPERTY: $date$year] x [GT [ATOM:2004.0]]]]
# [UNION: [JOIN: [PROPERTY: $next] x [UNARY: $records]] ^ [ARGMIN: [UNARY: $records] [PROPERTY: $index]]]
# [UNION: [JOIN: [PROPERTY: $number] x [LTE [ATOM:2004.0]]] ^ [ARGMIN: [NORMALIZE 2004] [PROPERTY: $number]]]
# [UNION: [JOIN: [PROPERTY: $number] x [EQ [ATOM:2004.0]]] ^ [JOIN: [PROPERTY: $number] x [LTE [ATOM:2004.0]]]]
# [INTERSECTION: [JOIN: [PROPERTY: $date$year] x [GTE [ATOM:2004.0]]] ^ [ARGMIN: [DATE Y: 2004 M: None D:None]  [PROPERTY: $date$year]]]
# [UNION: [JOIN: [PROPERTY: $number] x [EQ [ATOM:2004.0]]] ^ [NORMALIZE 2004]]
# [INTERSECTION: [JOIN: [PROPERTY: $date$year] x [GTE [ATOM:2004.0]]] ^ [JOIN: [PROPERTY: $date$year] x [EQ [ATOM:2004.0]]]]
# [INTERSECTION: [JOIN: [PROPERTY: $date$year] x [GTE [ATOM:2004.0]]] ^ [JOIN: [PROPERTY: $date$year] x [ATOM:2004.0]]]
# [UNION: [JOIN: [PROPERTY: $next] x [UNARY: $records]] ^ [UNARY: $records]]
# [JOIN: [PROPERTY: $index] x [LT [ATOM:2004.0]]]
# [INTERSECTION: [JOIN: [PROPERTY: $date$year] x [GTE [ATOM:2004.0]]] ^ [JOIN: [PROPERTY: $date$year] x [NEQ [ATOM:2004.0]]]]
# [INTERSECTION: [JOIN: [PROPERTY: $number] x [ATOM:2004.0]] ^ [JOIN: [PROPERTY: $date] x [DATE Y: 2004 M: None D:None] ]]
# [UNION: [ARGMIN: [DATE Y: 2004 M: None D:None]  [PROPERTY: $date$year]] ^ [DATE Y: 2004 M: None D:None] ]
# [JOIN: [PROPERTY: $number] x [EQ [ATOM:2004.0]]]
# [UNION: [ARGMIN: [DATE Y: 2004 M: None D:None]  [PROPERTY: $date$year]] ^ [JOIN: [PROPERTY: $date$year] x [GT [ATOM:2004.0]]]]
# [INTERSECTION: [JOIN: [PROPERTY: $number] x [ATOM:2004.0]] ^ [ARGMIN: [NORMALIZE 2004] [PROPERTY: $number]]]
# [UNION: [JOIN: [PROPERTY: $number] x [EQ [ATOM:2004.0]]] ^ [JOIN: [PROPERTY: $number] x [NEQ [ATOM:2004.0]]]]
# [INTERSECTION: [JOIN: [PROPERTY: $number] x [ATOM:2004.0]] ^ [NORMALIZE 2004]]
# [UNION: [JOIN: [PROPERTY: $date] x [DATE Y: 2004 M: None D:None] ] ^ [JOIN: [PROPERTY: $number] x [LTE [ATOM:2004.0]]]]
# [UNION: [JOIN: [PROPERTY: $date$year] x [GT [ATOM:2004.0]]] ^ [JOIN: [PROPERTY: $date$year] x [GTE [ATOM:2004.0]]]]
# [INTERSECTION: [JOIN: [PROPERTY: $number] x [ATOM:2004.0]] ^ [JOIN: [PROPERTY: $number] x [GTE [ATOM:2004.0]]]]
# [INTERSECTION: [JOIN: [PROPERTY: $number] x [ATOM:2004.0]] ^ [JOIN: [PROPERTY: $number] x [EQ [ATOM:2004.0]]]]
# [INTERSECTION: [JOIN: [PROPERTY: $number] x [ATOM:2004.0]] ^ [ARGMAX: [NORMALIZE 2004] [PROPERTY: $number]]]
# [UNION: [JOIN: [PROPERTY: $date$year] x [GT [ATOM:2004.0]]] ^ [JOIN: [PROPERTY: $date$year] x [NEQ [ATOM:2004.0]]]]
# [INTERSECTION: [JOIN: [PROPERTY: $number] x [ATOM:2004.0]] ^ [JOIN: [PROPERTY: $number] x [LTE [ATOM:2004.0]]]]
# [UNION: [COUNT: [DATE Y: 2004 M: None D:None] ] ^ [COUNT: [ENTITY:Greece]]]
# [UNION: [JOIN: [PROPERTY: $next] x [UNARY: $records]] ^ [JOIN: [PROPERTY: Country] x [ENTITY:Greece]]]
# [JOIN: [PROPERTY: $number] x [LTE [ATOM:2004.0]]]
# [UNION: [JOIN: [PROPERTY: $number] x [EQ [ATOM:2004.0]]] ^ [JOIN: [PROPERTY: $number] x [GT [ATOM:2004.0]]]]
# [UNION: [JOIN: [PROPERTY: $date] x [DATE Y: 2004 M: None D:None] ] ^ [ARGMAX: [NORMALIZE 2004] [PROPERTY: $number]]]
# [UNION: [COUNT: [DATE Y: 2004 M: None D:None] ] ^ [SUM: [ATOM:2004.0]]]
# [UNION: [JOIN: [PROPERTY: $number] x [EQ [ATOM:2004.0]]] ^ [JOIN: [PROPERTY: $date] x [DATE Y: 2004 M: None D:None] ]]
# [UNION: [COUNT: [DATE Y: 2004 M: None D:None] ] ^ [MIN: [ATOM:2004.0]]]
# [UNION: [JOIN: [PROPERTY: $next] x [UNARY: $records]] ^ [JOIN: [PROPERTY: $index] x [NEQ [ATOM:2004.0]]]]
# [UNION: [COUNT: [DATE Y: 2004 M: None D:None] ] ^ [ATOM:2004.0]]
# [UNION: [COUNT: [DATE Y: 2004 M: None D:None] ] ^ [AVG: [ATOM:2004.0]]]
# [UNION: [JOIN: [PROPERTY: $number] x [EQ [ATOM:2004.0]]] ^ [ARGMAX: [NORMALIZE 2004] [PROPERTY: $number]]]
# [JOIN: [CHAIN: [PROPERTY: Year] x [PROPERTY: $number]] x [GT [ATOM:2004.0]]]
# [UNION: [COUNT: [DATE Y: 2004 M: None D:None] ] ^ [MAX: [ATOM:2004.0]]]
# [UNION: [JOIN: [PROPERTY: Year] x [NORMALIZE 2004]] ^ [JOIN: [PROPERTY: $index] x [NEQ [ATOM:2004.0]]]]
# [UNION: [COUNT: [DATE Y: 2004 M: None D:None] ] ^ [COUNT: [ATOM:2004.0]]]
# [UNION: [COUNT: [DATE Y: 2004 M: None D:None] ] ^ [COUNT: [UNARY: $records]]]
# [INTERSECTION: [JOIN: [PROPERTY: Year] x [NORMALIZE 2004]] ^ [JOIN: [PROPERTY: $index] x [NEQ [ATOM:2004.0]]]]
# [UNION: [JOIN: [PROPERTY: $next] x [UNARY: $records]] ^ [ARGMAX: [UNARY: $records] [PROPERTY: $index]]]
# [UNION: [COUNT: [DATE Y: 2004 M: None D:None] ] ^ [COUNT: [NORMALIZE 2004]]]
# [UNION: [JOIN: [PROPERTY: $date$year] x [LT [ATOM:2004.0]]] ^ [ARGMAX: [DATE Y: 2004 M: None D:None]  [PROPERTY: $date$year]]]
# [UNION: [JOIN: [PROPERTY: $number] x [EQ [ATOM:2004.0]]] ^ [JOIN: [PROPERTY: $number] x [ATOM:2004.0]]]
# [JOIN: [CHAIN: [PROPERTY: $date] x [PROPERTY: $date$year]] x [LT [ATOM:2004.0]]]
# [UNION: [JOIN: [PROPERTY: $date$year] x [GT [ATOM:2004.0]]] ^ [ARGMAX: [DATE Y: 2004 M: None D:None]  [PROPERTY: $date$year]]]
# [UNION: [JOIN: [PROPERTY: $date$year] x [LT [ATOM:2004.0]]] ^ [JOIN: [PROPERTY: $date$year] x [LTE [ATOM:2004.0]]]]
# [UNION: [JOIN: [PROPERTY: $date] x [DATE Y: 2004 M: None D:None] ] ^ [JOIN: [PROPERTY: $number] x [ATOM:2004.0]]]
# [UNION: [JOIN: [PROPERTY: $next] x [UNARY: $records]] ^ [JOIN: [PROPERTY: Year] x [NORMALIZE 2004]]]
# [UNION: [JOIN: [PROPERTY: $date$year] x [LT [ATOM:2004.0]]] ^ [DATE Y: 2004 M: None D:None] ]
# [JOIN: [CHAIN: [PROPERTY: $date] x [PROPERTY: $date$year]] x [LTE [ATOM:2004.0]]]
# [JOIN: [CHAIN: [PROPERTY: $date] x [PROPERTY: $date$year]] x [GT [ATOM:2004.0]]]
# [UNION: [JOIN: [PROPERTY: $date$year] x [LT [ATOM:2004.0]]] ^ [JOIN: [PROPERTY: $date$year] x [GT [ATOM:2004.0]]]]
# [UNION: [JOIN: [PROPERTY: $number] x [EQ [ATOM:2004.0]]] ^ [JOIN: [PROPERTY: $number] x [GTE [ATOM:2004.0]]]]
# [JOIN: [CHAIN: [PROPERTY: Year] x [PROPERTY: $number]] x [GTE [ATOM:2004.0]]]
# [UNION: [JOIN: [PROPERTY: Year] x [NORMALIZE 2004]] ^ [ARGMIN: [UNARY: $records] [PROPERTY: $index]]]
# [UNION: [JOIN: [PROPERTY: $date$year] x [LT [ATOM:2004.0]]] ^ [ARGMIN: [DATE Y: 2004 M: None D:None]  [PROPERTY: $date$year]]]
# [JOIN: [CHAIN: [PROPERTY: Year] x [PROPERTY: $number]] x [LT [ATOM:2004.0]]]
# [UNION: [JOIN: [PROPERTY: $date$year] x [LT [ATOM:2004.0]]] ^ [JOIN: [PROPERTY: $date$year] x [EQ [ATOM:2004.0]]]]
# [UNION: [JOIN: [PROPERTY: $date$year] x [LT [ATOM:2004.0]]] ^ [JOIN: [PROPERTY: $date$year] x [ATOM:2004.0]]]
# [UNION: [JOIN: [PROPERTY: $next] x [UNARY: $records]] ^ [JOIN: [PROPERTY: $index] x [LT [ATOM:2004.0]]]]
# [UNION: [JOIN: [PROPERTY: $date$year] x [LT [ATOM:2004.0]]] ^ [JOIN: [PROPERTY: $date$year] x [NEQ [ATOM:2004.0]]]]
# [JOIN: [CHAIN: [PROPERTY: Year] x [PROPERTY: $number]] x [EQ [ATOM:2004.0]]]
# [UNION: [JOIN: [PROPERTY: $date$year] x [LT [ATOM:2004.0]]] ^ [JOIN: [PROPERTY: $date$year] x [GTE [ATOM:2004.0]]]]
# [UNION: [JOIN: [PROPERTY: $date$year] x [GT [ATOM:2004.0]]] ^ [DATE Y: 2004 M: None D:None] ]
# [JOIN: [PROPERTY: $date$year] x [GTE [ATOM:2004.0]]]
# [UNION: [JOIN: [PROPERTY: $number] x [GT [ATOM:2004.0]]] ^ [JOIN: [PROPERTY: $date] x [DATE Y: 2004 M: None D:None] ]]
# [UNION: [ARGMIN: [DATE Y: 2004 M: None D:None]  [PROPERTY: $date$year]] ^ [ARGMAX: [DATE Y: 2004 M: None D:None]  [PROPERTY: $date$year]]]
# [JOIN: [CHAIN: [PROPERTY: Nations] x [PROPERTY: $number]] x [NEQ [ATOM:2004.0]]]
# [UNION: [JOIN: [PROPERTY: Year] x [NORMALIZE 2004]] ^ [JOIN: [PROPERTY: $index] x [LT [ATOM:2004.0]]]]
# [UNION: [JOIN: [PROPERTY: $number] x [GT [ATOM:2004.0]]] ^ [JOIN: [PROPERTY: $number] x [NEQ [ATOM:2004.0]]]]
# [UNION: [ARGMIN: [UNARY: $records] [PROPERTY: $index]] ^ [JOIN: [PROPERTY: Country] x [ENTITY:Greece]]]
# [UNION: [ARGMIN: [UNARY: $records] [PROPERTY: $index]] ^ [JOIN: [PROPERTY: $index] x [NEQ [ATOM:2004.0]]]]
# [UNION: [JOIN: [PROPERTY: $date$year] x [GT [ATOM:2004.0]]] ^ [ARGMIN: [DATE Y: 2004 M: None D:None]  [PROPERTY: $date$year]]]
# [UNION: [JOIN: [PROPERTY: $number] x [GT [ATOM:2004.0]]] ^ [ARGMIN: [NORMALIZE 2004] [PROPERTY: $number]]]
# [UNION: [JOIN: [PROPERTY: $number] x [GT [ATOM:2004.0]]] ^ [NORMALIZE 2004]]
# [UNION: [ARGMIN: [DATE Y: 2004 M: None D:None]  [PROPERTY: $date$year]] ^ [JOIN: [PROPERTY: $date$year] x [LT [ATOM:2004.0]]]]
# [JOIN: R[[PROPERTY: $date$year]] x [ARGMAX: [DATE Y: 2004 M: None D:None]  [PROPERTY: $date$year]]]
# [UNION: [ARGMIN: [UNARY: $records] [PROPERTY: $index]] ^ [JOIN: [PROPERTY: Year] x [NORMALIZE 2004]]]
# [UNION: [JOIN: [PROPERTY: $number] x [GT [ATOM:2004.0]]] ^ [JOIN: [PROPERTY: $number] x [LT [ATOM:2004.0]]]]
# [JOIN: [CHAIN: [PROPERTY: Year] x [PROPERTY: $number]] x [LTE [ATOM:2004.0]]]
# [UNION: [JOIN: [PROPERTY: $number] x [GT [ATOM:2004.0]]] ^ [JOIN: [PROPERTY: $number] x [GTE [ATOM:2004.0]]]]
# [UNION: [JOIN: [PROPERTY: $number] x [GT [ATOM:2004.0]]] ^ [JOIN: [PROPERTY: $number] x [EQ [ATOM:2004.0]]]]
# [JOIN: [PROPERTY: $date$year] x [EQ [ATOM:2004.0]]]
# [UNION: [JOIN: [PROPERTY: $number] x [GT [ATOM:2004.0]]] ^ [JOIN: [PROPERTY: $number] x [LTE [ATOM:2004.0]]]]
# [UNION: [JOIN: [PROPERTY: $next] x [UNARY: $records]] ^ [JOIN: [PROPERTY: $index] x [LTE [ATOM:2004.0]]]]
# [UNION: [JOIN: [PROPERTY: $date$year] x [GT [ATOM:2004.0]]] ^ [JOIN: [PROPERTY: $date$year] x [EQ [ATOM:2004.0]]]]
# [UNION: [JOIN: [PROPERTY: $number] x [GT [ATOM:2004.0]]] ^ [JOIN: [PROPERTY: $number] x [ATOM:2004.0]]]
# [JOIN: [PROPERTY: $date$year] x [LTE [ATOM:2004.0]]]
# [UNION: [JOIN: [PROPERTY: $number] x [GT [ATOM:2004.0]]] ^ [ARGMAX: [NORMALIZE 2004] [PROPERTY: $number]]]
# [UNION: [ARGMIN: [DATE Y: 2004 M: None D:None]  [PROPERTY: $date$year]] ^ [JOIN: [PROPERTY: $date$year] x [EQ [ATOM:2004.0]]]]
# [JOIN: [PROPERTY: $index] x [NEQ [ATOM:2004.0]]]
# [JOIN: [PROPERTY: $date$year] x [GT [ATOM:2004.0]]]
# [UNION: [COUNT: [ENTITY:Greece]] ^ [COUNT: [DATE Y: 2004 M: None D:None] ]]
# [UNION: [COUNT: [ENTITY:Greece]] ^ [SUM: [ATOM:2004.0]]]
# [UNION: [JOIN: [PROPERTY: $number] x [EQ [ATOM:2004.0]]] ^ [JOIN: [PROPERTY: $number] x [LT [ATOM:2004.0]]]]
# [JOIN: [PROPERTY: $index] x [LTE [ATOM:2004.0]]]
# [UNION: [COUNT: [ENTITY:Greece]] ^ [MIN: [ATOM:2004.0]]]
# [UNION: [COUNT: [ENTITY:Greece]] ^ [ATOM:2004.0]]
# [UNION: [COUNT: [ENTITY:Greece]] ^ [AVG: [ATOM:2004.0]]]
# [UNION: [JOIN: [PROPERTY: $number] x [EQ [ATOM:2004.0]]] ^ [ARGMIN: [NORMALIZE 2004] [PROPERTY: $number]]]
# [JOIN: [PROPERTY: $number] x [NEQ [ATOM:2004.0]]]
# [UNION: [COUNT: [ENTITY:Greece]] ^ [MAX: [ATOM:2004.0]]]
# [UNION: [JOIN: [PROPERTY: Year] x [NORMALIZE 2004]] ^ [JOIN: [PROPERTY: Country] x [ENTITY:Greece]]]
# [UNION: [ARGMIN: [DATE Y: 2004 M: None D:None]  [PROPERTY: $date$year]] ^ [JOIN: [PROPERTY: $date$year] x [ATOM:2004.0]]]
# [UNION: [COUNT: [ENTITY:Greece]] ^ [COUNT: [ATOM:2004.0]]]
# [JOIN: [CHAIN: [PROPERTY: $date] x [PROPERTY: $date$year]] x [EQ [ATOM:2004.0]]]
# [UNION: [COUNT: [ENTITY:Greece]] ^ [COUNT: [UNARY: $records]]]
# [COUNT: [JOIN: [PROPERTY: $number] x [ATOM:2004.0]]]
# [JOIN: [PROPERTY: $number] x [AVG: [ATOM:2004.0]]]
# [JOIN: [PROPERTY: $number] x [LT [ATOM:2004.0]]]
# [UNION: [COUNT: [ENTITY:Greece]] ^ [COUNT: [NORMALIZE 2004]]]
# [UNION: [JOIN: [PROPERTY: Year] x [NORMALIZE 2004]] ^ [UNARY: $records]]
# [UNION: [MIN: [ATOM:2004.0]] ^ [COUNT: [DATE Y: 2004 M: None D:None] ]]
# [UNION: [MAX: [ATOM:2004.0]] ^ [COUNT: [ATOM:2004.0]]]
# [UNION: [JOIN: [PROPERTY: $date$year] x [GT [ATOM:2004.0]]] ^ [JOIN: [PROPERTY: $date$year] x [ATOM:2004.0]]]
# [UNION: [MIN: [ATOM:2004.0]] ^ [COUNT: [ENTITY:Greece]]]
# [UNION: [MIN: [ATOM:2004.0]] ^ [SUM: [ATOM:2004.0]]]
# [JOIN: [PROPERTY: $date$year] x [NEQ [ATOM:2004.0]]]
# [UNION: [MIN: [ATOM:2004.0]] ^ [AVG: [ATOM:2004.0]]]
# [UNION: [MIN: [ATOM:2004.0]] ^ [COUNT: [ATOM:2004.0]]]
# [UNION: [MIN: [ATOM:2004.0]] ^ [MAX: [ATOM:2004.0]]]
# [JOIN: [CHAIN: [PROPERTY: $date] x [PROPERTY: $date$year]] x [GTE [ATOM:2004.0]]]
# [UNION: [MIN: [ATOM:2004.0]] ^ [ATOM:2004.0]]
# [UNION: [MIN: [ATOM:2004.0]] ^ [COUNT: [UNARY: $records]]]
# [UNION: [MIN: [ATOM:2004.0]] ^ [COUNT: [NORMALIZE 2004]]]
# [UNION: [JOIN: [PROPERTY: $date] x [DATE Y: 2004 M: None D:None] ] ^ [JOIN: [PROPERTY: $number] x [GT [ATOM:2004.0]]]]
# [JOIN: [PROPERTY: $number] x [GTE [ATOM:2004.0]]]
# [JOIN: [CHAIN: [PROPERTY: Nations] x [PROPERTY: $number]] x [LTE [ATOM:2004.0]]]
# [UNION: [JOIN: [PROPERTY: $date] x [DATE Y: 2004 M: None D:None] ] ^ [JOIN: [PROPERTY: $number] x [NEQ [ATOM:2004.0]]]]
# [UNION: [JOIN: [PROPERTY: $date] x [DATE Y: 2004 M: None D:None] ] ^ [ARGMIN: [NORMALIZE 2004] [PROPERTY: $number]]]
# [UNION: [JOIN: [PROPERTY: $date$year] x [GTE [ATOM:2004.0]]] ^ [JOIN: [PROPERTY: $date$year] x [LTE [ATOM:2004.0]]]]
# [UNION: [JOIN: [PROPERTY: $date] x [DATE Y: 2004 M: None D:None] ] ^ [NORMALIZE 2004]]
# [JOIN: [PROPERTY: $date$year] x [LT [ATOM:2004.0]]]
# [UNION: [JOIN: [PROPERTY: $date] x [DATE Y: 2004 M: None D:None] ] ^ [JOIN: [PROPERTY: $number] x [LT [ATOM:2004.0]]]]
# [UNION: [JOIN: [PROPERTY: $date] x [DATE Y: 2004 M: None D:None] ] ^ [JOIN: [PROPERTY: $number] x [GTE [ATOM:2004.0]]]]
# [JOIN: [CHAIN: [PROPERTY: Nations] x [PROPERTY: $number]] x [LT [ATOM:2004.0]]]
# [UNION: [JOIN: [PROPERTY: $date] x [DATE Y: 2004 M: None D:None] ] ^ [JOIN: [PROPERTY: $number] x [EQ [ATOM:2004.0]]]]
# [ARGMIN: [JOIN: [PROPERTY: $index] x [LTE [ATOM:2004.0]]] [CHAIN: [PROPERTY: Year] x [PROPERTY: $number]]]
# [ARGMAX: [UNARY: $records] [CHAIN: [PROPERTY: Year] x [PROPERTY: $number]]]
# [ARGMAX: [UNARY: $records] [PROPERTY: $index]]
# [UNION: [ARGMIN: [UNARY: $records] [PROPERTY: $index]] ^ [JOIN: [PROPERTY: $next] x [UNARY: $records]]]
# [ARGMAX: [JOIN: [PROPERTY: $index] x [LT [ATOM:2004.0]]] [CHAIN: [PROPERTY: Year] x [PROPERTY: $number]]]
# [ARGMIN: [JOIN: [PROPERTY: $date$year] x [NEQ [ATOM:2004.0]]] [PROPERTY: $date$year]]
# [ARGMAX: [JOIN: [PROPERTY: $date$year] x [NEQ [ATOM:2004.0]]] [PROPERTY: $date$year]]
# [ARGMAX: [JOIN: [PROPERTY: $index] x [LTE [ATOM:2004.0]]] [CHAIN: [PROPERTY: Nations] x [PROPERTY: $number]]]
# [ARGMIN: [JOIN: [PROPERTY: $index] x [LT [ATOM:2004.0]]] [CHAIN: [PROPERTY: Year] x [PROPERTY: $number]]]
# [ARGMAX: [JOIN: [PROPERTY: $date$year] x [EQ [ATOM:2004.0]]] [PROPERTY: $date$year]]
# [ARGMIN: [UNARY: $records] [CHAIN: [PROPERTY: Year] x [PROPERTY: $number]]]
# [ARGMIN: [JOIN: [PROPERTY: $index] x [LTE [ATOM:2004.0]]] [PROPERTY: $index]]
# [ARGMIN: [UNARY: $records] [CHAIN: [PROPERTY: $next] x [PROPERTY: $index]]]
# [ARGMAX: [UNARY: $records] [CHAIN: [PROPERTY: $next] x [PROPERTY: $index]]]
# [ARGMAX: [JOIN: [PROPERTY: $index] x [LTE [ATOM:2004.0]]] [PROPERTY: $index]]
# [ARGMAX: [JOIN: [PROPERTY: $index] x [LT [ATOM:2004.0]]] [CHAIN: [PROPERTY: Nations] x [PROPERTY: $number]]]
# [ARGMIN: [ARGMAX: [UNARY: $records] [PROPERTY: $index]] [PROPERTY: $index]]
# [ARGMAX: [JOIN: [PROPERTY: $index] x [LT [ATOM:2004.0]]] [PROPERTY: $index]]
# [ARGMIN: [JOIN: [PROPERTY: $index] x [LTE [ATOM:2004.0]]] [CHAIN: [PROPERTY: Nations] x [PROPERTY: $number]]]
# [ARGMAX: [JOIN: [PROPERTY: $index] x [LTE [ATOM:2004.0]]] [CHAIN: [PROPERTY: Year] x [PROPERTY: $number]]]
# [ARGMIN: [JOIN: [PROPERTY: $index] x [LT [ATOM:2004.0]]] [PROPERTY: $index]]
# [ARGMAX: [ARGMIN: [DATE Y: 2004 M: None D:None]  [PROPERTY: $date$year]] [PROPERTY: $date$year]]
# [UNION: [ARGMIN: [UNARY: $records] [PROPERTY: $index]] ^ [UNARY: $records]]
# [ARGMIN: [JOIN: [PROPERTY: $index] x [LTE [ATOM:2004.0]]] [CHAIN: [PROPERTY: $next] x [PROPERTY: $index]]]
# [ARGMAX: [JOIN: [PROPERTY: $index] x [LTE [ATOM:2004.0]]] [CHAIN: [PROPERTY: $next] x [PROPERTY: $index]]]
# [ARGMAX: [JOIN: [PROPERTY: Year] x [NORMALIZE 2004]] [PROPERTY: $index]]
# [ARGMIN: [JOIN: [PROPERTY: $date$year] x [EQ [ATOM:2004.0]]] [PROPERTY: $date$year]]
# [ARGMIN: [JOIN: [PROPERTY: $next] x [UNARY: $records]] [CHAIN: [PROPERTY: Nations] x [PROPERTY: $number]]]
# [ARGMAX: [ARGMAX: [UNARY: $records] [PROPERTY: $index]] [PROPERTY: $index]]
# [ARGMIN: [JOIN: [PROPERTY: $next] x [UNARY: $records]] [CHAIN: [PROPERTY: $next] x [PROPERTY: $index]]]
# [ARGMAX: [JOIN: [PROPERTY: $number] x [EQ [ATOM:2004.0]]] [CHAIN: [PROPERTY: $date] x [PROPERTY: $date$year]]]
# [ARGMIN: [JOIN: [PROPERTY: $index] x [LT [ATOM:2004.0]]] [CHAIN: [PROPERTY: Nations] x [PROPERTY: $number]]]
# [ARGMAX: [JOIN: [PROPERTY: $next] x [UNARY: $records]] [CHAIN: [PROPERTY: Nations] x [PROPERTY: $number]]]
# [ARGMIN: [JOIN: [PROPERTY: $index] x [LT [ATOM:2004.0]]] [CHAIN: [PROPERTY: $next] x [PROPERTY: $index]]]
# [JOIN: R[[PROPERTY: City]] x [JOIN: [PROPERTY: Country] x [ENTITY:Greece]]]
# [ARGMAX: [JOIN: [PROPERTY: $index] x [LT [ATOM:2004.0]]] [CHAIN: [PROPERTY: $next] x [PROPERTY: $index]]]
# [ARGMAX: [JOIN: [PROPERTY: $number] x [EQ [ATOM:2004.0]]] [PROPERTY: $number]]
# [ARGMAX: [JOIN: [PROPERTY: $date$year] x [ATOM:2004.0]] [PROPERTY: $date$year]]
# [ARGMIN: [JOIN: [PROPERTY: $date$year] x [ATOM:2004.0]] [PROPERTY: $date$year]]
# [ARGMIN: [JOIN: [PROPERTY: $number] x [LTE [ATOM:2004.0]]] [PROPERTY: $number]]
# [ARGMIN: [JOIN: [PROPERTY: $number] x [EQ [ATOM:2004.0]]] [PROPERTY: $number]]
# [ARGMIN: [JOIN: [PROPERTY: $number] x [LTE [ATOM:2004.0]]] [CHAIN: [PROPERTY: $date] x [PROPERTY: $date$year]]]
# [ARGMAX: [JOIN: [PROPERTY: $number] x [LTE [ATOM:2004.0]]] [CHAIN: [PROPERTY: $date] x [PROPERTY: $date$year]]]
# [UNARY: $records]
# [ARGMIN: [JOIN: [PROPERTY: Year] x [NORMALIZE 2004]] [CHAIN: [PROPERTY: Nations] x [PROPERTY: $number]]]
# [ARGMAX: [JOIN: [PROPERTY: $next] x [UNARY: $records]] [PROPERTY: $index]]
# [UNION: [ARGMIN: [UNARY: $records] [PROPERTY: $index]] ^ [JOIN: [PROPERTY: $index] x [LT [ATOM:2004.0]]]]
# [ARGMAX: [JOIN: [PROPERTY: $number] x [LTE [ATOM:2004.0]]] [PROPERTY: $number]]
# [ARGMAX: [JOIN: [PROPERTY: $next] x [UNARY: $records]] [CHAIN: [PROPERTY: $next] x [PROPERTY: $index]]]
# [ARGMIN: [JOIN: [PROPERTY: $number] x [EQ [ATOM:2004.0]]] [CHAIN: [PROPERTY: $date] x [PROPERTY: $date$year]]]
# [ARGMIN: [ARGMIN: [DATE Y: 2004 M: None D:None]  [PROPERTY: $date$year]] [PROPERTY: $date$year]]
# [UNION: [ARGMIN: [UNARY: $records] [PROPERTY: $index]] ^ [ARGMAX: [UNARY: $records] [PROPERTY: $index]]]
# [ARGMIN: [JOIN: [PROPERTY: $next] x [UNARY: $records]] [PROPERTY: $index]]
# [ARGMAX: [JOIN: [PROPERTY: $next] x [UNARY: $records]] [CHAIN: [PROPERTY: Year] x [PROPERTY: $number]]]
# [ARGMAX: [JOIN: [PROPERTY: Year] x [NORMALIZE 2004]] [CHAIN: [PROPERTY: $next] x [PROPERTY: $index]]]
# [ARGMAX: [JOIN: [PROPERTY: Year] x [NORMALIZE 2004]] [CHAIN: [PROPERTY: Year] x [PROPERTY: $number]]]
# [ARGMAX: [JOIN: [PROPERTY: Year] x [NORMALIZE 2004]] [CHAIN: [PROPERTY: Nations] x [PROPERTY: $number]]]
# [ARGMIN: [JOIN: [PROPERTY: $next] x [UNARY: $records]] [CHAIN: [PROPERTY: Year] x [PROPERTY: $number]]]
# [ARGMIN: [JOIN: [PROPERTY: $number] x [GTE [ATOM:2004.0]]] [PROPERTY: $number]]
# [ARGMIN: [JOIN: [PROPERTY: $index] x [NEQ [ATOM:2004.0]]] [CHAIN: [PROPERTY: $next] x [PROPERTY: $index]]]
# [ARGMIN: [JOIN: [PROPERTY: $number] x [LT [ATOM:2004.0]]] [PROPERTY: $number]]
# [ARGMIN: [JOIN: [PROPERTY: $date$year] x [GT [ATOM:2004.0]]] [PROPERTY: $date$year]]
# [ARGMIN: [JOIN: [PROPERTY: Year] x [NORMALIZE 2004]] [PROPERTY: $index]]
# [UNION: [ARGMIN: [UNARY: $records] [PROPERTY: $index]] ^ [JOIN: [PROPERTY: $index] x [LTE [ATOM:2004.0]]]]
# [ARGMAX: [JOIN: [PROPERTY: $index] x [NEQ [ATOM:2004.0]]] [CHAIN: [PROPERTY: $next] x [PROPERTY: $index]]]
# [ARGMIN: [JOIN: [PROPERTY: Year] x [NORMALIZE 2004]] [CHAIN: [PROPERTY: Year] x [PROPERTY: $number]]]
# [ARGMAX: [JOIN: [PROPERTY: $number] x [LT [ATOM:2004.0]]] [CHAIN: [PROPERTY: $date] x [PROPERTY: $date$year]]]
# [UNION: [ARGMAX: [UNARY: $records] [PROPERTY: $index]] ^ [JOIN: [PROPERTY: Country] x [ENTITY:Greece]]]
# [ARGMAX: [JOIN: [PROPERTY: $date$year] x [GT [ATOM:2004.0]]] [PROPERTY: $date$year]]
# [ARGMIN: [JOIN: [PROPERTY: $number] x [GTE [ATOM:2004.0]]] [CHAIN: [PROPERTY: $date] x [PROPERTY: $date$year]]]
# [ARGMAX: [JOIN: [PROPERTY: $index] x [NEQ [ATOM:2004.0]]] [PROPERTY: $index]]
# [ARGMAX: [JOIN: [PROPERTY: $number] x [GTE [ATOM:2004.0]]] [PROPERTY: $number]]
# [ARGMIN: [JOIN: [PROPERTY: Year] x [NORMALIZE 2004]] [CHAIN: [PROPERTY: $next] x [PROPERTY: $index]]]
# [ARGMIN: [JOIN: [PROPERTY: $number] x [LT [ATOM:2004.0]]] [CHAIN: [PROPERTY: $date] x [PROPERTY: $date$year]]]
# [ARGMIN: [JOIN: [PROPERTY: $index] x [NEQ [ATOM:2004.0]]] [CHAIN: [PROPERTY: Year] x [PROPERTY: $number]]]
# [ARGMAX: [JOIN: [PROPERTY: $number] x [GTE [ATOM:2004.0]]] [CHAIN: [PROPERTY: $date] x [PROPERTY: $date$year]]]
# [ARGMIN: [JOIN: [PROPERTY: $index] x [NEQ [ATOM:2004.0]]] [PROPERTY: $index]]
# [ARGMIN: [JOIN: [PROPERTY: $index] x [NEQ [ATOM:2004.0]]] [CHAIN: [PROPERTY: Nations] x [PROPERTY: $number]]]
# [ARGMAX: [JOIN: [PROPERTY: $index] x [NEQ [ATOM:2004.0]]] [CHAIN: [PROPERTY: Year] x [PROPERTY: $number]]]
# [ARGMAX: [JOIN: [PROPERTY: $index] x [NEQ [ATOM:2004.0]]] [CHAIN: [PROPERTY: Nations] x [PROPERTY: $number]]]
# [ARGMAX: [JOIN: [PROPERTY: $date$year] x [GTE [ATOM:2004.0]]] [PROPERTY: $date$year]]
# [UNION: [JOIN: [PROPERTY: $number] x [NEQ [ATOM:2004.0]]] ^ [JOIN: [PROPERTY: $date] x [DATE Y: 2004 M: None D:None] ]]
# [ARGMIN: [ARGMAX: [NORMALIZE 2004] [PROPERTY: $number]] [CHAIN: [PROPERTY: $date] x [PROPERTY: $date$year]]]
# [UNION: [SUM: [ATOM:2004.0]] ^ [COUNT: [ENTITY:Greece]]]
# [UNION: [ARGMAX: [DATE Y: 2004 M: None D:None]  [PROPERTY: $date$year]] ^ [JOIN: [PROPERTY: $date$year] x [GTE [ATOM:2004.0]]]]
# [ARGMIN: [UNARY: $records] [CHAIN: [PROPERTY: Nations] x [PROPERTY: $number]]]
# [UNION: [AVG: [ATOM:2004.0]] ^ [COUNT: [UNARY: $records]]]
# [ARGMIN: [JOIN: [PROPERTY: $date$year] x [GTE [ATOM:2004.0]]] [PROPERTY: $date$year]]
# [UNION: [SUM: [ATOM:2004.0]] ^ [COUNT: [DATE Y: 2004 M: None D:None] ]]
# [ARGMAX: [ARGMAX: [NORMALIZE 2004] [PROPERTY: $number]] [PROPERTY: $number]]
# [ARGMIN: [UNARY: $records] [PROPERTY: $index]]
# [UNION: [SUM: [ATOM:2004.0]] ^ [AVG: [ATOM:2004.0]]]
# [UNION: [ARGMIN: [NORMALIZE 2004] [PROPERTY: $number]] ^ [NORMALIZE 2004]]
# [ARGMAX: [UNARY: $records] [CHAIN: [PROPERTY: Nations] x [PROPERTY: $number]]]
# [UNION: [ARGMAX: [UNARY: $records] [PROPERTY: $index]] ^ [JOIN: [PROPERTY: Year] x [NORMALIZE 2004]]]
# [ARGMIN: [JOIN: [PROPERTY: $number] x [ATOM:2004.0]] [PROPERTY: $number]]
# [ARGMAX: [ARGMAX: [NORMALIZE 2004] [PROPERTY: $number]] [CHAIN: [PROPERTY: $date] x [PROPERTY: $date$year]]]
# [ARGMIN: [ARGMAX: [NORMALIZE 2004] [PROPERTY: $number]] [PROPERTY: $number]]
# [INTERSECTION: [SUM: [ATOM:2004.0]] ^ [ATOM:2004.0]]
# [UNION: [SUM: [ATOM:2004.0]] ^ [MAX: [ATOM:2004.0]]]
# [ARGMIN: [JOIN: [PROPERTY: $number] x [ATOM:2004.0]] [CHAIN: [PROPERTY: $date] x [PROPERTY: $date$year]]]
# [UNION: [SUM: [ATOM:2004.0]] ^ [COUNT: [UNARY: $records]]]
# [ARGMAX: [JOIN: [PROPERTY: $number] x [ATOM:2004.0]] [PROPERTY: $number]]
# [JOIN: [PROPERTY: $date] x [ARGMAX: [DATE Y: 2004 M: None D:None]  [PROPERTY: $date$year]]]
# [UNION: [ARGMIN: [NORMALIZE 2004] [PROPERTY: $number]] ^ [JOIN: [PROPERTY: $number] x [GT [ATOM:2004.0]]]]
# [UNION: [ARGMAX: [DATE Y: 2004 M: None D:None]  [PROPERTY: $date$year]] ^ [JOIN: [PROPERTY: $date$year] x [LT [ATOM:2004.0]]]]
# [JOIN: [PROPERTY: $date] x [JOIN: [PROPERTY: $date$year] x [LT [ATOM:2004.0]]]]
# [UNION: [SUM: [ATOM:2004.0]] ^ [MIN: [ATOM:2004.0]]]
# [JOIN: [PROPERTY: $date] x [JOIN: [PROPERTY: $date$year] x [GT [ATOM:2004.0]]]]
# [JOIN: [PROPERTY: $date] x [JOIN: [PROPERTY: $date$year] x [EQ [ATOM:2004.0]]]]
# [UNION: [ARGMAX: [DATE Y: 2004 M: None D:None]  [PROPERTY: $date$year]] ^ [JOIN: [PROPERTY: $date$year] x [ATOM:2004.0]]]
# [JOIN: [PROPERTY: $date] x [JOIN: [PROPERTY: $date$year] x [LTE [ATOM:2004.0]]]]
# [JOIN: [PROPERTY: $date] x [JOIN: [PROPERTY: $date$year] x [ATOM:2004.0]]]
# [UNION: [ARGMIN: [NORMALIZE 2004] [PROPERTY: $number]] ^ [JOIN: [PROPERTY: $date] x [DATE Y: 2004 M: None D:None] ]]
# [JOIN: R[[PROPERTY: $next]] x [JOIN: [PROPERTY: $index] x [NEQ [ATOM:2004.0]]]]
# [JOIN: [PROPERTY: $date] x [JOIN: [PROPERTY: $date$year] x [GTE [ATOM:2004.0]]]]
# [INTERSECTION: [JOIN: [PROPERTY: $number] x [GTE [ATOM:2004.0]]] ^ [JOIN: [PROPERTY: $date] x [DATE Y: 2004 M: None D:None] ]]
# [JOIN: R[[PROPERTY: $next]] x [JOIN: [PROPERTY: $index] x [LT [ATOM:2004.0]]]]
# [UNION: [ATOM:2004.0] ^ [MIN: [ATOM:2004.0]]]
# [UNION: [ARGMAX: [DATE Y: 2004 M: None D:None]  [PROPERTY: $date$year]] ^ [JOIN: [PROPERTY: $date$year] x [LTE [ATOM:2004.0]]]]
# [JOIN: [PROPERTY: $date] x [ARGMIN: [DATE Y: 2004 M: None D:None]  [PROPERTY: $date$year]]]
# [JOIN: R[[PROPERTY: $next]] x [JOIN: [PROPERTY: $index] x [LTE [ATOM:2004.0]]]]
# [UNION: [ARGMAX: [DATE Y: 2004 M: None D:None]  [PROPERTY: $date$year]] ^ [JOIN: [PROPERTY: $date$year] x [GT [ATOM:2004.0]]]]
# [UNION: [ARGMAX: [DATE Y: 2004 M: None D:None]  [PROPERTY: $date$year]] ^ [JOIN: [PROPERTY: $date$year] x [EQ [ATOM:2004.0]]]]
# [JOIN: R[[PROPERTY: $next]] x [UNARY: $records]]
# [UNION: [ARGMAX: [DATE Y: 2004 M: None D:None]  [PROPERTY: $date$year]] ^ [JOIN: [PROPERTY: $date$year] x [NEQ [ATOM:2004.0]]]]
# [JOIN: R[[PROPERTY: $next]] x [JOIN: [PROPERTY: Country] x [ENTITY:Greece]]]
# [ARGMAX: [JOIN: [PROPERTY: $number] x [ATOM:2004.0]] [CHAIN: [PROPERTY: $date] x [PROPERTY: $date$year]]]
# [UNION: [JOIN: [PROPERTY: $number] x [NEQ [ATOM:2004.0]]] ^ [JOIN: [PROPERTY: $number] x [GT [ATOM:2004.0]]]]
# [JOIN: R[[PROPERTY: Country]] x [JOIN: [PROPERTY: $index] x [NEQ [ATOM:2004.0]]]]
# [UNION: [JOIN: [PROPERTY: $number] x [NEQ [ATOM:2004.0]]] ^ [ARGMIN: [NORMALIZE 2004] [PROPERTY: $number]]]
# [INTERSECTION: [JOIN: [PROPERTY: $number] x [GTE [ATOM:2004.0]]] ^ [JOIN: [PROPERTY: $number] x [GT [ATOM:2004.0]]]]
# [UNION: [ATOM:2004.0] ^ [COUNT: [NORMALIZE 2004]]]
# [JOIN: R[[PROPERTY: Country]] x [JOIN: [PROPERTY: Country] x [ENTITY:Greece]]]
# [INTERSECTION: [JOIN: [PROPERTY: $index] x [NEQ [ATOM:2004.0]]] ^ [UNARY: $records]]
# [JOIN: R[[PROPERTY: Country]] x [JOIN: [PROPERTY: $index] x [LT [ATOM:2004.0]]]]
# [INTERSECTION: [JOIN: [PROPERTY: $index] x [NEQ [ATOM:2004.0]]] ^ [JOIN: [PROPERTY: $index] x [LTE [ATOM:2004.0]]]]
# [UNION: [JOIN: [PROPERTY: Country] x [ENTITY:Greece]] ^ [JOIN: [PROPERTY: $index] x [LTE [ATOM:2004.0]]]]
# [UNION: [ARGMAX: [DATE Y: 2004 M: None D:None]  [PROPERTY: $date$year]] ^ [DATE Y: 2004 M: None D:None] ]
# [INTERSECTION: [JOIN: [PROPERTY: $index] x [NEQ [ATOM:2004.0]]] ^ [ARGMAX: [UNARY: $records] [PROPERTY: $index]]]
# [JOIN: R[[PROPERTY: $next]] x [JOIN: [PROPERTY: Year] x [NORMALIZE 2004]]]
# [INTERSECTION: [JOIN: [PROPERTY: $index] x [NEQ [ATOM:2004.0]]] ^ [JOIN: [PROPERTY: $index] x [LT [ATOM:2004.0]]]]
# [ENTITY:Greece]
# [JOIN: R[[PROPERTY: Country]] x [UNARY: $records]]
# [INTERSECTION: [JOIN: [PROPERTY: $index] x [NEQ [ATOM:2004.0]]] ^ [JOIN: [PROPERTY: $next] x [UNARY: $records]]]
# [JOIN: [PROPERTY: $date] x [JOIN: [PROPERTY: $date$year] x [NEQ [ATOM:2004.0]]]]
# [UNION: [SUM: [ATOM:2004.0]] ^ [ATOM:2004.0]]
# [JOIN: [PROPERTY: $date] x [DATE Y: 2004 M: None D:None] ]
# [UNION: [AVG: [ATOM:2004.0]] ^ [SUM: [ATOM:2004.0]]]
# [INTERSECTION: [JOIN: [PROPERTY: $index] x [NEQ [ATOM:2004.0]]] ^ [JOIN: [PROPERTY: Year] x [NORMALIZE 2004]]]
# [UNION: [JOIN: [PROPERTY: $number] x [NEQ [ATOM:2004.0]]] ^ [JOIN: [PROPERTY: $number] x [LT [ATOM:2004.0]]]]
# [INTERSECTION: [JOIN: [PROPERTY: $index] x [NEQ [ATOM:2004.0]]] ^ [JOIN: [PROPERTY: Country] x [ENTITY:Greece]]]
# [JOIN: R[[PROPERTY: Country]] x [JOIN: [PROPERTY: Year] x [NORMALIZE 2004]]]
# [JOIN: R[[PROPERTY: Country]] x [JOIN: [PROPERTY: $index] x [LTE [ATOM:2004.0]]]]
# [UNION: [JOIN: [PROPERTY: Country] x [ENTITY:Greece]] ^ [JOIN: [PROPERTY: $index] x [LT [ATOM:2004.0]]]]
# [INTERSECTION: [JOIN: [PROPERTY: $index] x [NEQ [ATOM:2004.0]]] ^ [ARGMIN: [UNARY: $records] [PROPERTY: $index]]]
# [JOIN: [CHAIN: [PROPERTY: $next] x [PROPERTY: Nations]] x [JOIN: [PROPERTY: $number] x [LT [ATOM:2004.0]]]]
# [INTERSECTION: [COUNT: [ATOM:2004.0]] ^ [COUNT: [NORMALIZE 2004]]]
# [UNION: [ARGMIN: [NORMALIZE 2004] [PROPERTY: $number]] ^ [JOIN: [PROPERTY: $number] x [NEQ [ATOM:2004.0]]]]
# [INTERSECTION: [COUNT: [ATOM:2004.0]] ^ [COUNT: [ENTITY:Greece]]]
# [JOIN: R[[PROPERTY: $next]] x [JOIN: [PROPERTY: $next] x [UNARY: $records]]]
# [UNION: [JOIN: [PROPERTY: $number] x [NEQ [ATOM:2004.0]]] ^ [JOIN: [PROPERTY: $number] x [EQ [ATOM:2004.0]]]]
# [INTERSECTION: [JOIN: [PROPERTY: $number] x [LT [ATOM:2004.0]]] ^ [JOIN: [PROPERTY: $number] x [LTE [ATOM:2004.0]]]]
# [JOIN: R[[PROPERTY: $next]] x [ARGMIN: [UNARY: $records] [PROPERTY: $index]]]
# [JOIN: R[[PROPERTY: Country]] x [JOIN: [PROPERTY: $next] x [UNARY: $records]]]
# [UNION: [JOIN: [PROPERTY: $number] x [NEQ [ATOM:2004.0]]] ^ [ARGMAX: [NORMALIZE 2004] [PROPERTY: $number]]]
# [INTERSECTION: [COUNT: [ATOM:2004.0]] ^ [COUNT: [DATE Y: 2004 M: None D:None] ]]
# [JOIN: R[[PROPERTY: Country]] x [ARGMIN: [UNARY: $records] [PROPERTY: $index]]]
# [INTERSECTION: [JOIN: [PROPERTY: $number] x [LT [ATOM:2004.0]]] ^ [JOIN: [PROPERTY: $number] x [NEQ [ATOM:2004.0]]]]
# [UNION: [JOIN: [PROPERTY: $number] x [NEQ [ATOM:2004.0]]] ^ [NORMALIZE 2004]]
# [INTERSECTION: [NORMALIZE 2004] ^ [JOIN: [PROPERTY: $number] x [ATOM:2004.0]]]
# [UNION: [ATOM:2004.0] ^ [MAX: [ATOM:2004.0]]]
# [JOIN: [CHAIN: [PROPERTY: $next] x [PROPERTY: Nations]] x [JOIN: [PROPERTY: $number] x [NEQ [ATOM:2004.0]]]]
# [JOIN: [CHAIN: [PROPERTY: $next] x [PROPERTY: Nations]] x [JOIN: [PROPERTY: $number] x [LTE [ATOM:2004.0]]]]
# [INTERSECTION: [NORMALIZE 2004] ^ [ARGMAX: [NORMALIZE 2004] [PROPERTY: $number]]]
# [UNION: [AVG: [ATOM:2004.0]] ^ [COUNT: [DATE Y: 2004 M: None D:None] ]]
# [JOIN: [PROPERTY: Year] x [JOIN: [PROPERTY: $number] x [GT [ATOM:2004.0]]]]
# [UNION: [AVG: [ATOM:2004.0]] ^ [MIN: [ATOM:2004.0]]]
# [INTERSECTION: [NORMALIZE 2004] ^ [JOIN: [PROPERTY: $number] x [LTE [ATOM:2004.0]]]]
# [INTERSECTION: [NORMALIZE 2004] ^ [JOIN: [PROPERTY: $number] x [EQ [ATOM:2004.0]]]]
# [UNION: [AVG: [ATOM:2004.0]] ^ [COUNT: [ATOM:2004.0]]]
# [JOIN: [PROPERTY: Year] x [ARGMIN: [NORMALIZE 2004] [PROPERTY: $number]]]
# [UNION: [AVG: [ATOM:2004.0]] ^ [ATOM:2004.0]]
# [INTERSECTION: [NORMALIZE 2004] ^ [JOIN: [PROPERTY: $number] x [GTE [ATOM:2004.0]]]]
# [JOIN: [PROPERTY: Year] x [JOIN: [PROPERTY: $date] x [DATE Y: 2004 M: None D:None] ]]
# [UNION: [UNARY: $records] ^ [JOIN: [PROPERTY: Country] x [ENTITY:Greece]]]
# ...
# [JOIN: [PROPERTY: $date$year] x [MAX: [ATOM:2004.0]]]
# [INTERSECTION: [JOIN: [PROPERTY: $number] x [EQ [ATOM:2004.0]]] ^ [JOIN: [PROPERTY: $date] x [DATE Y: 2004 M: None D:None] ]]
# [UNION: [JOIN: [PROPERTY: $date$year] x [GTE [ATOM:2004.0]]] ^ [ARGMAX: [DATE Y: 2004 M: None D:None]  [PROPERTY: $date$year]]]
# [COUNT: [JOIN: [PROPERTY: $number] x [LTE [ATOM:2004.0]]]]
# [UNION: [MAX: [ATOM:2004.0]] ^ [COUNT: [DATE Y: 2004 M: None D:None] ]]
# [JOIN: R[[PROPERTY: Nations]] x [JOIN: [PROPERTY: $index] x [LT [ATOM:2004.0]]]]
# [UNION: [JOIN: [PROPERTY: $date$year] x [EQ [ATOM:2004.0]]] ^ [JOIN: [PROPERTY: $date$year] x [NEQ [ATOM:2004.0]]]]
# [JOIN: [CHAIN: [PROPERTY: Year] x [PROPERTY: $number]] x [MAX: [ATOM:2004.0]]]
# [COUNT: [ARGMIN: [DATE Y: 2004 M: None D:None]  [PROPERTY: $date$year]]]
# [UNION: [JOIN: [PROPERTY: $date$year] x [EQ [ATOM:2004.0]]] ^ [JOIN: [PROPERTY: $date$year] x [LT [ATOM:2004.0]]]]
# [JOIN: [CHAIN: [PROPERTY: Year] x [PROPERTY: $number]] x [AVG: [ATOM:2004.0]]]
# [COUNT: [JOIN: [PROPERTY: $number] x [EQ [ATOM:2004.0]]]]
# [COUNT: [JOIN: [PROPERTY: $next] x [UNARY: $records]]]
# [UNION: [JOIN: [PROPERTY: $date$year] x [EQ [ATOM:2004.0]]] ^ [JOIN: [PROPERTY: $date$year] x [GT [ATOM:2004.0]]]]
# [JOIN: R[[PROPERTY: Nations]] x [UNARY: $records]]
# [COUNT: [JOIN: [PROPERTY: Year] x [NORMALIZE 2004]]]
# [JOIN: [CHAIN: [PROPERTY: Year] x [PROPERTY: $number]] x [SUM: [ATOM:2004.0]]]
# [UNION: [MAX: [ATOM:2004.0]] ^ [ATOM:2004.0]]
# [COUNT: [JOIN: [PROPERTY: $date$year] x [GT [ATOM:2004.0]]]]
# [UNION: [COUNT: [UNARY: $records]] ^ [COUNT: [DATE Y: 2004 M: None D:None] ]]
# [JOIN: [CHAIN: [PROPERTY: Year] x [PROPERTY: $number]] x [ATOM:2004.0]]
# [UNION: [JOIN: [PROPERTY: $date$year] x [ATOM:2004.0]] ^ [JOIN: [PROPERTY: $date$year] x [LT [ATOM:2004.0]]]]
# [JOIN: R[[PROPERTY: Nations]] x [JOIN: [PROPERTY: $next] x [UNARY: $records]]]
# [CHAIN: R[[PROPERTY: City]] x [CHAIN: [PROPERTY: Nations] x [PROPERTY: $number]]]
# [CHAIN: [PROPERTY: $next] x [PROPERTY: City]]
# [CHAIN: R[[PROPERTY: $next]] x [CHAIN: [PROPERTY: Nations] x [PROPERTY: $date]]]
# [CHAIN: R[[PROPERTY: Country]] x [PROPERTY: Year]]
# [CHAIN: R[[PROPERTY: $index]] x [CHAIN: [PROPERTY: $next] x [PROPERTY: City]]]
# [CHAIN: R[[PROPERTY: $next]] x R[[PROPERTY: $next]]]
# [PROPERTY: Nations]
# [CHAIN: [CHAIN: [PROPERTY: $next] x [PROPERTY: Nations]] x [CHAIN: [PROPERTY: $date] x [PROPERTY: $date$year]]]
# R[[PROPERTY: $date$year]]
# [CHAIN: [PROPERTY: $next] x [PROPERTY: Year]]
# [CHAIN: R[[PROPERTY: Year]] x [CHAIN: [PROPERTY: Nations] x [PROPERTY: $date]]]
# [CHAIN: R[[PROPERTY: Nations]] x [PROPERTY: $index]]
# [CHAIN: R[[PROPERTY: Country]] x [PROPERTY: $next]]
# [CHAIN: R[[PROPERTY: $next]] x [PROPERTY: Country]]
# [CHAIN: R[[PROPERTY: $index]] x [PROPERTY: Nations]]
# [CHAIN: R[[PROPERTY: Year]] x R[[PROPERTY: $next]]]
# [CHAIN: R[[PROPERTY: $date]] x [CHAIN: [PROPERTY: $date] x [PROPERTY: $date$year]]]
# [CHAIN: R[[PROPERTY: $index]] x [CHAIN: [PROPERTY: $next] x [PROPERTY: Year]]]
# [CHAIN: [PROPERTY: $next] x [PROPERTY: $next]]
# [CHAIN: R[[PROPERTY: City]] x [CHAIN: [PROPERTY: Nations] x [PROPERTY: $date]]]
# [CHAIN: R[[PROPERTY: Year]] x [PROPERTY: Country]]
# R[[CHAIN: [PROPERTY: Year] x [PROPERTY: $date]]]
# [CHAIN: R[[PROPERTY: $index]] x [CHAIN: [PROPERTY: $next] x [PROPERTY: $next]]]
# [CHAIN: R[[PROPERTY: Nations]] x [CHAIN: [PROPERTY: $next] x [PROPERTY: Country]]]
# [CHAIN: R[[PROPERTY: City]] x R[[PROPERTY: $next]]]
# [CHAIN: R[[PROPERTY: Country]] x [CHAIN: [PROPERTY: Year] x [PROPERTY: $number]]]
# [CHAIN: R[[PROPERTY: City]] x [PROPERTY: Country]]
# [CHAIN: [PROPERTY: $date] x [PROPERTY: $date$year]]
# [CHAIN: R[[PROPERTY: Country]] x [CHAIN: [PROPERTY: $next] x [PROPERTY: $index]]]
# [CHAIN: R[[PROPERTY: $number]] x [CHAIN: [PROPERTY: $date] x [PROPERTY: $date$year]]]
# [CHAIN: [CHAIN: [PROPERTY: $date] x [PROPERTY: $date$year]] x R[[PROPERTY: $number]]]
# [CHAIN: [PROPERTY: Nations] x [PROPERTY: $number]]
# [CHAIN: [PROPERTY: $next] x [CHAIN: [PROPERTY: Year] x [PROPERTY: $number]]]
# [CHAIN: [PROPERTY: $number] x R[[PROPERTY: $date$year]]]
# [CHAIN: R[[PROPERTY: $next]] x [CHAIN: [PROPERTY: $next] x [PROPERTY: Nations]]]
# [CHAIN: [CHAIN: [PROPERTY: Nations] x [PROPERTY: $number]] x R[[PROPERTY: $number]]]
# [CHAIN: [CHAIN: [PROPERTY: Nations] x [PROPERTY: $date]] x R[[PROPERTY: $date]]]
# R[[CHAIN: [PROPERTY: $next] x [PROPERTY: $index]]]
# [CHAIN: [CHAIN: [PROPERTY: $next] x [PROPERTY: Year]] x [PROPERTY: $number]]
# [CHAIN: R[[PROPERTY: $index]] x [CHAIN: [PROPERTY: Nations] x [PROPERTY: $number]]]
# [CHAIN: [PROPERTY: $next] x [CHAIN: [PROPERTY: $next] x [PROPERTY: $index]]]
# R[[CHAIN: [PROPERTY: Year] x [PROPERTY: $number]]]
# [CHAIN: [CHAIN: [PROPERTY: $next] x [PROPERTY: $next]] x [PROPERTY: $index]]
# [CHAIN: R[[PROPERTY: Year]] x [CHAIN: [PROPERTY: $next] x [PROPERTY: Nations]]]
# [CHAIN: R[[PROPERTY: Country]] x [CHAIN: [PROPERTY: Year] x [PROPERTY: $date]]]
# [CHAIN: R[[PROPERTY: $date]] x R[[PROPERTY: Year]]]
# [CHAIN: R[[PROPERTY: Nations]] x [PROPERTY: City]]
# [CHAIN: [CHAIN: [PROPERTY: $next] x [PROPERTY: $next]] x [CHAIN: [PROPERTY: $next] x [PROPERTY: Country]]]
# [CHAIN: [PROPERTY: Nations] x [PROPERTY: $date]]
# [CHAIN: R[[PROPERTY: City]] x [CHAIN: [PROPERTY: $next] x [PROPERTY: Nations]]]
# [CHAIN: [PROPERTY: $next] x [CHAIN: [PROPERTY: Year] x [PROPERTY: $date]]]
# [CHAIN: [CHAIN: [PROPERTY: $next] x [PROPERTY: Year]] x [PROPERTY: $date]]
# R[[PROPERTY: $next]]
# [CHAIN: R[[PROPERTY: $index]] x [CHAIN: [PROPERTY: Nations] x [PROPERTY: $date]]]
# [CHAIN: R[[PROPERTY: Nations]] x [PROPERTY: Year]]
# [CHAIN: R[[PROPERTY: $index]] x R[[PROPERTY: $next]]]
# [PROPERTY: Country]
# R[[PROPERTY: Year]]
# [CHAIN: R[[PROPERTY: Nations]] x [PROPERTY: $next]]
# [CHAIN: R[[PROPERTY: $number]] x R[[PROPERTY: Year]]]
# [CHAIN: R[[PROPERTY: $index]] x [PROPERTY: Country]]
# [CHAIN: R[[PROPERTY: Country]] x [CHAIN: [PROPERTY: $next] x [PROPERTY: City]]]
# R[[PROPERTY: City]]
# [CHAIN: [PROPERTY: $next] x [CHAIN: [PROPERTY: $next] x [PROPERTY: City]]]
# [CHAIN: [CHAIN: [PROPERTY: $next] x [PROPERTY: $next]] x [PROPERTY: City]]
# [CHAIN: R[[PROPERTY: $next]] x [PROPERTY: $index]]
# [CHAIN: R[[PROPERTY: Country]] x [PROPERTY: Nations]]
# [CHAIN: R[[PROPERTY: Country]] x [CHAIN: [PROPERTY: $next] x [PROPERTY: Year]]]
# [CHAIN: R[[PROPERTY: Nations]] x [CHAIN: [PROPERTY: Year] x [PROPERTY: $number]]]
# [CHAIN: R[[PROPERTY: Year]] x [PROPERTY: $index]]
# [CHAIN: [PROPERTY: $next] x [PROPERTY: Nations]]
# [CHAIN: [PROPERTY: $next] x [CHAIN: [PROPERTY: $next] x [PROPERTY: Year]]]
# [CHAIN: R[[PROPERTY: Nations]] x [PROPERTY: Nations]]
# [CHAIN: [PROPERTY: Country] x R[[PROPERTY: Country]]]
# [CHAIN: R[[PROPERTY: Country]] x [CHAIN: [PROPERTY: $next] x [PROPERTY: $next]]]
# [CHAIN: R[[PROPERTY: Nations]] x [CHAIN: [PROPERTY: $next] x [PROPERTY: $index]]]
# [CHAIN: [PROPERTY: $next] x R[[PROPERTY: $next]]]
# [CHAIN: R[[PROPERTY: Year]] x [PROPERTY: Year]]
# [CHAIN: [PROPERTY: Year] x R[[PROPERTY: Year]]]
# [CHAIN: R[[PROPERTY: City]] x [PROPERTY: City]]
# [CHAIN: [PROPERTY: City] x R[[PROPERTY: City]]]
# [CHAIN: R[[PROPERTY: $date$year]] x [PROPERTY: $date$year]]
# [CHAIN: R[[PROPERTY: $next]] x [CHAIN: [PROPERTY: $next] x [PROPERTY: Country]]]
# R[[PROPERTY: $date]]
# [CHAIN: R[[PROPERTY: $index]] x [CHAIN: [PROPERTY: $next] x [PROPERTY: Nations]]]
# [CHAIN: [CHAIN: [PROPERTY: $next] x [PROPERTY: $next]] x [PROPERTY: $next]]
# [CHAIN: [PROPERTY: $next] x [CHAIN: [PROPERTY: $next] x [PROPERTY: $next]]]
# [CHAIN: R[[PROPERTY: City]] x [PROPERTY: $index]]
# [CHAIN: R[[PROPERTY: Year]] x [CHAIN: [PROPERTY: $next] x [PROPERTY: Country]]]
# [CHAIN: [CHAIN: [PROPERTY: Year] x [PROPERTY: $date]] x [PROPERTY: $date$year]]
# [CHAIN: [PROPERTY: Year] x [CHAIN: [PROPERTY: $date] x [PROPERTY: $date$year]]]
# R[[CHAIN: [PROPERTY: $next] x [PROPERTY: Country]]]
# [CHAIN: R[[PROPERTY: Nations]] x [CHAIN: [PROPERTY: Year] x [PROPERTY: $date]]]
# [CHAIN: [PROPERTY: $date$year] x R[[PROPERTY: $date$year]]]
# [CHAIN: [CHAIN: [PROPERTY: Year] x [PROPERTY: $number]] x R[[PROPERTY: $date$year]]]
# [CHAIN: R[[PROPERTY: Country]] x [CHAIN: [PROPERTY: Nations] x [PROPERTY: $number]]]
# [CHAIN: R[[PROPERTY: City]] x [CHAIN: [PROPERTY: $next] x [PROPERTY: Country]]]
# [PROPERTY: $date$month]
# R[[PROPERTY: $number]]
# [CHAIN: [PROPERTY: $next] x [CHAIN: [PROPERTY: Nations] x [PROPERTY: $number]]]
# [CHAIN: [CHAIN: [PROPERTY: $next] x [PROPERTY: Nations]] x [PROPERTY: $number]]
# [CHAIN: [CHAIN: [PROPERTY: $next] x [PROPERTY: $next]] x [CHAIN: [PROPERTY: Year] x [PROPERTY: $number]]]
# R[[PROPERTY: $index]]
# [CHAIN: R[[PROPERTY: $date]] x [PROPERTY: $number]]
# [CHAIN: [CHAIN: [PROPERTY: $next] x [PROPERTY: $next]] x [CHAIN: [PROPERTY: $next] x [PROPERTY: $index]]]
# [CHAIN: R[[PROPERTY: $next]] x [PROPERTY: City]]
# [CHAIN: R[[PROPERTY: Country]] x [CHAIN: [PROPERTY: Nations] x [PROPERTY: $date]]]
# [CHAIN: R[[PROPERTY: Year]] x [PROPERTY: City]]
# [CHAIN: R[[PROPERTY: Nations]] x [CHAIN: [PROPERTY: $next] x [PROPERTY: City]]]
# [PROPERTY: $date$day]
# [CHAIN: R[[PROPERTY: Country]] x R[[PROPERTY: $next]]]
# [CHAIN: R[[PROPERTY: $next]] x [PROPERTY: Year]]
# [PROPERTY: $index]
# [CHAIN: [CHAIN: [PROPERTY: $next] x [PROPERTY: Nations]] x [PROPERTY: $date]]
# [CHAIN: [PROPERTY: $next] x [CHAIN: [PROPERTY: Nations] x [PROPERTY: $date]]]
# [CHAIN: [CHAIN: [PROPERTY: $next] x [PROPERTY: $next]] x [CHAIN: [PROPERTY: Year] x [PROPERTY: $date]]]
# [PROPERTY: $number]
# [CHAIN: [PROPERTY: $number] x R[[PROPERTY: $number]]]
# [CHAIN: R[[PROPERTY: $number]] x [PROPERTY: $number]]
# [CHAIN: R[[PROPERTY: Country]] x [PROPERTY: Country]]
# [CHAIN: R[[PROPERTY: $next]] x [PROPERTY: $next]]
# [CHAIN: [PROPERTY: $index] x R[[PROPERTY: $index]]]
# [CHAIN: R[[PROPERTY: $index]] x [PROPERTY: $index]]
# [CHAIN: R[[PROPERTY: $date]] x [PROPERTY: $date]]
# [CHAIN: R[[PROPERTY: Nations]] x [CHAIN: [PROPERTY: $next] x [PROPERTY: Year]]]
# [CHAIN: [PROPERTY: $date] x R[[PROPERTY: $date]]]
# [CHAIN: [PROPERTY: Nations] x R[[PROPERTY: Nations]]]
# [CHAIN: [PROPERTY: $next] x [PROPERTY: Country]]
# [CHAIN: R[[PROPERTY: Year]] x [PROPERTY: $next]]
# [CHAIN: R[[PROPERTY: Nations]] x [CHAIN: [PROPERTY: $next] x [PROPERTY: $next]]]
# [CHAIN: R[[PROPERTY: City]] x [PROPERTY: Year]]
# [CHAIN: R[[PROPERTY: $index]] x [CHAIN: [PROPERTY: $next] x [PROPERTY: Country]]]
# [PROPERTY: $date]
# [CHAIN: R[[PROPERTY: City]] x [PROPERTY: $next]]
# [CHAIN: R[[PROPERTY: $next]] x [CHAIN: [PROPERTY: Year] x [PROPERTY: $number]]]
# [CHAIN: R[[PROPERTY: $number]] x [PROPERTY: $date]]
# [CHAIN: [CHAIN: [PROPERTY: $next] x [PROPERTY: $next]] x [CHAIN: [PROPERTY: $next] x [PROPERTY: City]]]
# R[[CHAIN: [PROPERTY: $next] x [PROPERTY: Nations]]]
# [CHAIN: R[[PROPERTY: $next]] x [CHAIN: [PROPERTY: $next] x [PROPERTY: $index]]]
# [CHAIN: R[[PROPERTY: Country]] x [CHAIN: [PROPERTY: $next] x [PROPERTY: Nations]]]
# [CHAIN: R[[PROPERTY: Nations]] x [CHAIN: [PROPERTY: Nations] x [PROPERTY: $number]]]
# [CHAIN: R[[PROPERTY: Year]] x [CHAIN: [PROPERTY: Year] x [PROPERTY: $number]]]
# [CHAIN: [CHAIN: [PROPERTY: $next] x [PROPERTY: $next]] x [PROPERTY: Nations]]
# [CHAIN: [PROPERTY: $next] x [CHAIN: [PROPERTY: $next] x [PROPERTY: Nations]]]
# [CHAIN: [CHAIN: [PROPERTY: $next] x [PROPERTY: $next]] x [CHAIN: [PROPERTY: $next] x [PROPERTY: Year]]]
# [CHAIN: R[[PROPERTY: Year]] x [CHAIN: [PROPERTY: $next] x [PROPERTY: $index]]]
# [PROPERTY: City]
# [CHAIN: R[[PROPERTY: City]] x [CHAIN: [PROPERTY: Year] x [PROPERTY: $number]]]
# [CHAIN: R[[PROPERTY: $next]] x [CHAIN: [PROPERTY: Year] x [PROPERTY: $date]]]
# [CHAIN: [CHAIN: [PROPERTY: $next] x [PROPERTY: $next]] x [CHAIN: [PROPERTY: $next] x [PROPERTY: $next]]]
# [CHAIN: R[[PROPERTY: $index]] x [PROPERTY: City]]
# [CHAIN: R[[PROPERTY: City]] x [CHAIN: [PROPERTY: $next] x [PROPERTY: $index]]]
# [CHAIN: [PROPERTY: Nations] x [CHAIN: [PROPERTY: $date] x [PROPERTY: $date$year]]]
# [CHAIN: [CHAIN: [PROPERTY: $next] x [PROPERTY: $next]] x [PROPERTY: Year]]
# [PROPERTY: Year]
# [CHAIN: [CHAIN: [PROPERTY: Nations] x [PROPERTY: $date]] x [PROPERTY: $date$year]]
# [CHAIN: R[[PROPERTY: Year]] x [CHAIN: [PROPERTY: Year] x [PROPERTY: $date]]]
# [CHAIN: R[[PROPERTY: Nations]] x [CHAIN: [PROPERTY: Nations] x [PROPERTY: $date]]]
# R[[PROPERTY: Country]]
# [CHAIN: [CHAIN: [PROPERTY: $next] x [PROPERTY: Year]] x [CHAIN: [PROPERTY: $date] x [PROPERTY: $date$year]]]
# [CHAIN: [CHAIN: [PROPERTY: $date] x [PROPERTY: $date$year]] x R[[PROPERTY: $date$year]]]
# [CHAIN: [CHAIN: [PROPERTY: Nations] x [PROPERTY: $number]] x R[[PROPERTY: $date$year]]]
# [CHAIN: R[[PROPERTY: Nations]] x R[[PROPERTY: $next]]]
# [CHAIN: R[[PROPERTY: $index]] x [PROPERTY: Year]]
# [CHAIN: R[[PROPERTY: Country]] x [CHAIN: [PROPERTY: $next] x [PROPERTY: Country]]]
# [CHAIN: [CHAIN: [PROPERTY: $next] x [PROPERTY: $next]] x R[[PROPERTY: $next]]]
# [PROPERTY: $next]
# [CHAIN: R[[PROPERTY: City]] x [CHAIN: [PROPERTY: Year] x [PROPERTY: $date]]]
# [CHAIN: [CHAIN: [PROPERTY: $next] x [PROPERTY: $next]] x [CHAIN: [PROPERTY: Nations] x [PROPERTY: $number]]]
# [CHAIN: R[[PROPERTY: Nations]] x [PROPERTY: Country]]
# R[[CHAIN: [PROPERTY: Nations] x [PROPERTY: $date]]]
# [CHAIN: R[[PROPERTY: $index]] x [PROPERTY: $next]]
# [CHAIN: R[[PROPERTY: $next]] x [CHAIN: [PROPERTY: $next] x [PROPERTY: City]]]
# [CHAIN: R[[PROPERTY: Country]] x [PROPERTY: $index]]
# [CHAIN: [PROPERTY: Year] x [PROPERTY: $number]]
# [CHAIN: R[[PROPERTY: Year]] x [CHAIN: [PROPERTY: $next] x [PROPERTY: City]]]
# [CHAIN: R[[PROPERTY: $next]] x [PROPERTY: Nations]]
# [CHAIN: [CHAIN: [PROPERTY: Year] x [PROPERTY: $date]] x R[[PROPERTY: $date]]]
# [CHAIN: [CHAIN: [PROPERTY: Year] x [PROPERTY: $number]] x R[[PROPERTY: $number]]]
# [CHAIN: R[[PROPERTY: $next]] x [CHAIN: [PROPERTY: $next] x [PROPERTY: Year]]]
# [CHAIN: [PROPERTY: $next] x [PROPERTY: $index]]
# [CHAIN: [CHAIN: [PROPERTY: $next] x [PROPERTY: $next]] x [CHAIN: [PROPERTY: Nations] x [PROPERTY: $date]]]
# [CHAIN: R[[PROPERTY: $index]] x [CHAIN: [PROPERTY: Year] x [PROPERTY: $number]]]
# R[[CHAIN: [PROPERTY: Nations] x [PROPERTY: $number]]]
# R[[CHAIN: [PROPERTY: $date] x [PROPERTY: $date$year]]]
# [CHAIN: R[[PROPERTY: Year]] x [PROPERTY: Nations]]
# [CHAIN: R[[PROPERTY: Year]] x [CHAIN: [PROPERTY: $next] x [PROPERTY: Year]]]
# [CHAIN: [CHAIN: [PROPERTY: $next] x [PROPERTY: Year]] x R[[PROPERTY: Year]]]
# [CHAIN: R[[PROPERTY: City]] x [CHAIN: [PROPERTY: $next] x [PROPERTY: City]]]
# [CHAIN: [CHAIN: [PROPERTY: $next] x [PROPERTY: $index]] x R[[PROPERTY: $index]]]
# [CHAIN: [CHAIN: [PROPERTY: $next] x [PROPERTY: City]] x R[[PROPERTY: City]]]
# [CHAIN: R[[PROPERTY: Nations]] x [CHAIN: [PROPERTY: $next] x [PROPERTY: Nations]]]
# [CHAIN: [CHAIN: [PROPERTY: $next] x [PROPERTY: Nations]] x R[[PROPERTY: Nations]]]
# [CHAIN: R[[PROPERTY: $index]] x [CHAIN: [PROPERTY: $next] x [PROPERTY: $index]]]
# [CHAIN: R[[PROPERTY: $next]] x [CHAIN: [PROPERTY: $next] x [PROPERTY: $next]]]
# [CHAIN: [CHAIN: [PROPERTY: $next] x [PROPERTY: Country]] x R[[PROPERTY: Country]]]
# [CHAIN: R[[PROPERTY: $date]] x R[[PROPERTY: Nations]]]
# [CHAIN: [PROPERTY: $next] x [CHAIN: [PROPERTY: $next] x [PROPERTY: Country]]]
# [CHAIN: [CHAIN: [PROPERTY: $next] x [PROPERTY: $next]] x [PROPERTY: Country]]
# [CHAIN: R[[PROPERTY: Year]] x [CHAIN: [PROPERTY: $next] x [PROPERTY: $next]]]
# [CHAIN: R[[PROPERTY: City]] x [PROPERTY: Nations]]
# [CHAIN: [PROPERTY: Year] x [PROPERTY: $date]]
# [CHAIN: R[[PROPERTY: City]] x [CHAIN: [PROPERTY: $next] x [PROPERTY: Year]]]
# R[[CHAIN: [PROPERTY: $next] x [PROPERTY: $next]]]
# [CHAIN: R[[PROPERTY: $index]] x [CHAIN: [PROPERTY: Year] x [PROPERTY: $date]]]
# [CHAIN: R[[PROPERTY: $next]] x [CHAIN: [PROPERTY: Nations] x [PROPERTY: $number]]]
# [CHAIN: R[[PROPERTY: City]] x [CHAIN: [PROPERTY: $next] x [PROPERTY: $next]]]
# R[[CHAIN: [PROPERTY: $next] x [PROPERTY: Year]]]
# [PROPERTY: $date$year]
# R[[PROPERTY: Nations]]
# [CHAIN: [PROPERTY: $date$year] x R[[PROPERTY: $number]]]
# [CHAIN: R[[PROPERTY: $number]] x R[[PROPERTY: Nations]]]
# [CHAIN: R[[PROPERTY: Year]] x [CHAIN: [PROPERTY: Nations] x [PROPERTY: $number]]]
# [CHAIN: R[[PROPERTY: $date$year]] x R[[PROPERTY: $date]]]
# [CHAIN: R[[PROPERTY: Country]] x [PROPERTY: City]]
# [CHAIN: [CHAIN: [PROPERTY: $next] x [PROPERTY: $next]] x [CHAIN: [PROPERTY: $next] x [PROPERTY: Nations]]]
# R[[CHAIN: [PROPERTY: $next] x [PROPERTY: City]]]

# %%
def cross_product(list1,list2):
    return [(a,b) for a in list1 for b in list2]

def act_union(bits):
    if bits[0]
    
    if bits[0] != bits[1]:
        return [Union(bits[0],bits[1])]

def act_intersection(bits):
    return [Intersection(bits[0],bits[1])]

def act_join(bits):
    return [Join(bits[0],bits[1])]

def act_agg(u):
    if isinstance(u,Atom):
        return [Min(u), Max(u), Count(u), Avg(u), Sum(u)]
    return [Count(u)]
        
def act_sup(bits):
    u = bits[0]
    b = bits[1]
    return [ArgMin(u,b), ArgMax(u,b)]

def act_reverse(b):
    if isinstance(b,Reverse):
        return [b.b]
    return [Reverse(b)]

def act_chain(bs):
    b1 = bs[0]
    b2 = bs[1]
    return [Chain(b1,b2)]
    
def act_cmp(ua):
    u = ua[0]
    a = ua[1]
    
    return [Join(u, GreaterThan(a)),
            Join(u, GreaterThanEq(a)),
            Join(u, LessThan(a)),
            Join(u, LessThanEq(a)),
            Join(u, Eq(a)),
            Join(u, NEq(a)),
           ]
       


def transition(u,b,v_prods):
    atoms = [au for au in u if isinstance(au,Atom)]
    
    ab_actions = []# (act_cmp, cross_product(b,atoms)) ]
    
    u_actions = [( act_union , cross_product(u,u) ),
             ( act_intersection, cross_product(u,u) ),
             ( act_agg, u )
            ]

    bu_actions = [( act_join , cross_product(b,u) ),
                  ( act_sup, cross_product(u,b) )
                 ]

    b_actions = [ ( act_reverse, b),
                  ( act_chain, cross_product(b,b)) 
                ]


    print("Starting with " + str(len(u)) + " unaries")
    print("Starting with " + str(len(b)) + " binaries")
    
    u_next = set()
    b_next = set()
    
    for action,data in ab_actions:
        for datum in data:
            for a in action(datum):
                u_next.add((datum,a))
                

                
    for action,data in u_actions:
        for datum in data:
            for a in action(datum):
                u_next.add((datum,a))

    for action,data in bu_actions:
        for datum in data:
            for a in action(datum):
                u_next.add((datum,a))

    for action,data in b_actions:
        for datum in data:
            for a in action(datum):
                b_next.add((datum,a))

    print("Generated " + str(len(u_next)) + " unaries")
    print("Generated " + str(len(b_next)) + " binaries")    
    
    
    u_ret = set()
    b_ret = set()
    
    u_ret.update(u)
    b_ret.update(b)
    
    pruned = 0  
    
    for d,a in u_next:
        v = a.vals()
        

            
        if v is None:
            pruned += 1
            continue
        elif len(v) == 0:
            pruned += 1
            continue

        if Atom(2004.0) in v and len(v) == 1:
            v_prods.add(a)
            print("2004!")
            
        if hasattr(d,"__iter__"):
            if hasattr(v,"__iter__"):
                if set(d)==set(v):
                    pruned +=1
                    continue
        u_ret.add(a)
            
    print("Pruned "+ str(pruned) + " unaries")

    pruned = 0
    for d,a in b_next:
        v = a.vals()
            
        if v is None:
            pruned += 1
            continue
        elif len(v) == 0:
            pruned += 1
            continue
            
        if Atom(2004.0) in v and len(v) == 1:
            v_prods.add(a)
            print("2004!")
            
        if hasattr(d,"__iter__"):
            if hasattr(v,"__iter__"):
                if set(d)==set(v):
                    pruned +=1
                    continue

        b_ret.add(a)
    
    print("Pruned "+ str(pruned) + " binaries")
    return u_ret,b_ret,v_prods


u_,b_ = u,b
v_prods = set()
for i in range(2):
    print("Iteration " + str(i))
    u_, b_,v_prods = transition(u_,b_,v_prods)
    print("")
    
for d in v_prods:
    print(d)

# %%
print([str(a) for a in Join(Reverse(properties[0]), ArgMax(Join(properties[2],Entity("Greece")),index)).vals()])
print(Join(Reverse(properties[0]), ArgMax(Join(properties[2],Entity("Greece")),index)))

# %%
table = Table("towns.tsv")


properties = []
for prop in table.read()['header']:
    properties.append(Property(prop))


       
atoms = set()
entities = set()

row_id = 0
last_row = None

next_row = Property("$next")
index = Property("$index")

records = Unary("$records") 

properties.append(next_row)
properties.append(index)

for row in table.read()['rows']:
    r = Record("$"+str(row_id))
    
    index.add(r,Atom(row_id))
    
    col_id = 0 
    for col in row:

        if len(col.strip()) == 0:
            col_id +=1
            continue
            
        if is_number(col) or is_date(col):
            a = Atom(float(col))
            properties[col_id].add(r,a)
            atoms.add(a)
        else:
            e = Entity(col.strip())
            
            properties[col_id].add(r,e)
            entities.add(e)
        col_id += 1
 
    records.add(r)
    if last_row is not None:
        next_row.add(last_row,r)
    row_id += 1 
    last_row = r    


actions = [( ground_entity , t.nes ),
           ( ground_atom , t.nums ),
          ]

u = set()
b = set()

for action,data in actions:
    for datum in data:
        u.update(action(datum))

        
for p in properties:
    b.add(p)
    
u.add(records)
        


def transition(u,b,v_prods):
    u_actions = [( act_union , cross_product(u,u) ),
             ( act_intersection, cross_product(u,u) ),
             ( act_agg, u )
            ]

    bu_actions = [( act_join , cross_product(b,u) ),
                  ( act_sup, cross_product(u,b) )
                 ]

    b_actions = [ ( act_reverse, b),
                  ( act_chain, cross_product(b,b)) 
                ]


    print("Starting with " + str(len(u)) + " unaries")
    print("Starting with " + str(len(b)) + " binaries")
    
    u_next = set()
    b_next = set()
    
    for action,data in u_actions:
        for datum in data:
            for a in action(datum):
                u_next.add((datum,a))

    for action,data in bu_actions:
        for datum in data:
            for a in action(datum):
                u_next.add((datum,a))

    for action,data in b_actions:
        for datum in data:
            for a in action(datum):
                b_next.add((datum,a))

    print("Generated " + str(len(u_next)) + " unaries")
    print("Generated " + str(len(b_next)) + " binaries")    
    
    
    u_ret = set()
    b_ret = set()
    
    u_ret.update(u)
    b_ret.update(b)
    
    pruned = 0  
    
    for d,a in u_next:
        v = a.vals()
        

            
        if v is None:
            pruned += 1
            continue
        elif len(v) == 0:
            pruned += 1
            continue

        if Atom(2004.0) in v and len(v) == 1:
            v_prods.add(a)
            print("2004!")
            
        if hasattr(d,"__iter__"):
            if hasattr(v,"__iter__"):
                if set(d)==set(v):
                    pruned +=1
                    continue
        u_ret.add(a)
            
    print("Pruned "+ str(pruned) + " unaries")

    pruned = 0
    for d,a in b_next:
        v = a.vals()
            
        if v is None:
            pruned += 1
            continue
        elif len(v) == 0:
            pruned += 1
            continue
            
        if Atom(2004.0) in v and len(v) == 1:
            v_prods.add(a)
            print("2004!")
            
        if hasattr(d,"__iter__"):
            if hasattr(v,"__iter__"):
                if set(d)==set(v):
                    pruned +=1
                    continue

        b_ret.add(a)
    
    print("Pruned "+ str(pruned) + " binaries")
    return u_ret,b_ret,v_prods



    

print(GreaterThan(Atom(100)).compile()(Atom(10)))
print(GreaterThan(Atom(100)).compile()(Atom(110)))


#print([str(a) for a in Join(properties[1],GreaterThan(Atom(1000))).vals()])

print([str(a) for a in Join(Reverse(properties[0]), Join(properties[1],GreaterThan(Atom(1000)))).vals()])

#print(Join(Reverse(properties[1]),list(records.vals())[0]).vals())
#print([str(a) for a in Join22(Reverse(properties[3]),records).vals()])

# %%
t = TrainingExample("Greece last held its Summer Olympics since 2004?",None,None)

examples = ["2004", "September","93", "September 2004", "5th September 2005","3503432.3"]

from dateutil.parser import parser, parse



    
class NormalisationAtom():
    dateprops = Property("$date")
    numberprops = Property("$number")
    
    def __init__(self,value):
        self.value = value
        if is_date(value):
            self.dateprops.add(self,DateAtom(value))
        elif is_number(value):
            self.numberprops.add(self,Atom(float(value)))
            
    def __str__(self):
        return "[NORMALIZE "+str(self.value)+"]"
            
    def allprops():
        return {NormalisationAtom.dateprops,NormalisationAtom.numberprops}
    allprops = staticmethod(allprops)

class DateAtom():
    yearprops = Property("$date$year")
    monthprops = Property("$date$month")
    dayprops = Property("$date$day")
    
    def __init__(self,value):
        self.value = value
        
        res, _ = parser()._parse(value)
        if hasattr(res,"day") and res.day is not None:
            self.day = res.day
            self.dayprops.add(self,Atom(res.day))
        if hasattr(res,"month") and res.month is not None:
            self.month = res.month
            self.monthprops.add(self,Atom(res.month))
        if hasattr(res,"year") and res.year is not None:
            self.year = res.year
            self.yearprops.add(self,Atom(res.year))
            
            
    def __str__(self):
        return ("[DATE Y: " + (str(self.year) if hasattr(self,"year") else "None") 
                + " M: "+ (str(self.month) if hasattr(self,"month") else "None")
                + " D:" + (str(self.day) if hasattr(self,"day") else "None") +"] ")
    
            
    def allprops():
        return {DateAtom.yearprops,DateAtom.monthprops,DateAtom.dayprops}
    
    allprops = staticmethod(allprops)
    
    
    
    
table = Table("test.tsv")


properties = []
for prop in table.read()['header']:
    properties.append(Property(prop))


atoms = set()
entities = set()

row_id = 0
last_row = None

next_row = Property("$next")
index = Property("$index")

records = Unary("$records") 


for row in table.read()['rows']:
    r = Record("$"+str(row_id))
    
    index.add(r,Atom(row_id))
    
    col_id = 0 
    for col in row:

        if len(col.strip()) == 0:
            col_id +=1
            continue
            
        if is_number(col) or is_date(col):
            a = NormalisationAtom(col)
            properties[col_id].add(r,a)
            atoms.add(a)
        else:
            e = Entity(col.strip())
            
            properties[col_id].add(r,e)
            entities.add(e)
        col_id += 1
 
    records.add(r)
    if last_row is not None:
        next_row.add(last_row,r)
    row_id += 1 
    last_row = r    

    
properties.append(next_row)
properties.append(index)

properties.extend(NormalisationAtom.allprops())
properties.extend(DateAtom.allprops())


for num in t.nums: 
    print(NormalisationAtom(" ".join(num.tokens)))

# %% [raw]
#
#
#
# scores = Unary("scores")
# scores.add(Atom(100))
# scores.add(Atom(150))
# scores.add(Atom(200))
#
#
# print([str(a) for a in Add(Atom(100),Atom(100)).vals()])
# print([str(a) for a in Add(Atom(500),scores).vals()])
#
#
# print([str(a) for a in Subtract(Atom(100),Atom(100)).vals()])
# print([str(a) for a in Subtract(Atom(100),scores).vals()])
