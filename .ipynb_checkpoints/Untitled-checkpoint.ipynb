# %%
from parser.TokenSpan import TokenSpan
from training import *
from dcs.dcs import *
from table.TableToGraph import *
from dateutil.parser import parse as dparse
import unicodedata
import itertools
# Out:
# Loading spacy
# Done

# %%
atomic_types = ["DATE","TIME","PERCENT","MONEY","QUANTITY","ORDINAL","CARDINAL"]
entity_types = ["PERSON","NORP","FACILITY","ORG","GPE","LOC","PRODUCT","EVENT","LANGUAGE"]

class TrainingExample():
    def __init__(self,sentence, answer, table):
        doc = nlp(sentence)

        tokens = []
        espans = []
        nspans = []
        ne_start = -1
        for t in range(len(doc)):
            tokens.append(doc[t].text)
            if doc[t].ent_iob == 3:
                if ne_start >= 0:
                    if str(doc[ne_start].ent_type_) in entity_types:
                        espans.append((ne_start,t))
                    elif str(doc[ne_start].ent_type_) in atomic_types:
                        nspans.append((ne_start,t))
                else:
                    ne_start = t
            elif doc[t].ent_iob == 2:
                if ne_start >= 0:
                    if str(doc[ne_start].ent_type_) in entity_types:
                        espans.append((ne_start,t))
                    elif str(doc[ne_start].ent_type_) in atomic_types:
                        nspans.append((ne_start,t))
                    ne_start = -1

        token_spans = []
        for espan in espans:
            start = espan[0]
            end = espan[1]

            ts = TokenSpan(tokens,start,end)
            token_spans.append(ts)
        
        self.nes = token_spans
        token_spans = []
        for espan in nspans:
            start = espan[0]
            end = espan[1]

            ts = TokenSpan(tokens,start,end)
            token_spans.append(ts)
            
            
        self.words = tokens
        self.answer = answer
        self.table = table
        self.nums = token_spans

t = TrainingExample("Greece last held its Summer Olympics in which year?",None,None)

def ground_entity(ts):
    s = " ".join(ts.tokens)
    return [Entity(s)]


def ground_atom(ts):
    s = " ".join(ts.tokens)
    return [Atom(s)]

def is_date(string):
    try: 
        dparse(string)
        return True
    except ValueError:
        return False
    
def is_number(s):
    try:
        float(s)
        return True
    except ValueError:
        pass
 
    try:
        unicodedata.numeric(s)
        return True
    except (TypeError, ValueError):
        pass
 
    return False



def cross_product(list1,list2):
    return [(a,b) for a in list1 for b in list2]

def act_union(bits):
    return [Union(bits[0],bits[1])]

def act_intersection(bits):
    return [Intersection(bits[0],bits[1])]

def act_join(bits):
    return [Join(bits[0],bits[1])]

def act_agg(u):
    if isinstance(u,Atom):
        return [Min(u), Max(u), Count(u), Avg(u), Sum(u)]
    return [Count(u)]
        
def act_sup(bits):
    u = bits[0]
    b = bits[1]
    return [ArgMin(u,b), ArgMax(u,b)]

def act_reverse(b):
    if isinstance(b,Reverse):
        return [b.b]
    return [Reverse(b)]

def act_chain(bs):
    b1 = bs[0]
    b2 = bs[1]
    return [Chain(b1,b2)]
    

table = Table("test.tsv")


properties = []
for prop in table.read()['header']:
    properties.append(Property(prop))


       
atoms = set()
entities = set()

row_id = 0
last_row = None

next_row = Property("$next")
index = Property("$index")

records = Unary("$records") 

properties.append(next_row)
properties.append(index)

for row in table.read()['rows']:
    r = Record("$"+str(row_id))
    
    index.add(r,Atom(row_id))
    
    col_id = 0 
    for col in row:

        if len(col.strip()) == 0:
            col_id +=1
            continue
            
        if is_number(col) or is_date(col):
            a = Atom(float(col))
            properties[col_id].add(r,a)
            atoms.add(a)
        else:
            e = Entity(col.strip())
            
            properties[col_id].add(r,e)
            entities.add(e)
        col_id += 1
 
    records.add(r)
    if last_row is not None:
        next_row.add(last_row,r)
    row_id += 1 
    last_row = r    


actions = [( ground_entity , t.nes ),
           ( ground_atom , t.nums ),
          ]

u = set()
b = set()

for action,data in actions:
    for datum in data:
        u.update(action(datum))

        
for p in properties:
    b.add(p)
    
u.add(records)
        


def transition(u,b,v_prods):
    
    u_actions = [( act_union , cross_product(u,u) ),
             ( act_intersection, cross_product(u,u) ),
             ( act_agg, u )
            ]

    bu_actions = [( act_join , cross_product(b,u) ),
                  ( act_sup, cross_product(u,b) )
                 ]

    b_actions = [ ( act_reverse, b),
                  ( act_chain, cross_product(b,b)) 
                ]


    print("Starting with " + str(len(u)) + " unaries")
    print("Starting with " + str(len(b)) + " binaries")
    
    u_next = set()
    b_next = set()
    
    for action,data in u_actions:
        for datum in data:
            for a in action(datum):
                u_next.add((datum,a))

    for action,data in bu_actions:
        for datum in data:
            for a in action(datum):
                u_next.add((datum,a))

    for action,data in b_actions:
        for datum in data:
            for a in action(datum):
                b_next.add((datum,a))

    print("Generated " + str(len(u_next)) + " unaries")
    print("Generated " + str(len(b_next)) + " binaries")    
    
    
    u_ret = set()
    b_ret = set()
    
    u_ret.update(u)
    b_ret.update(b)
    
    pruned = 0  
    
    for d,a in u_next:
        v = a.vals()
        

            
        if v is None:
            pruned += 1
            continue
        elif len(v) == 0:
            pruned += 1
            continue

        if Atom(2004.0) in v and len(v) == 1:
            v_prods.add(a)
            print("2004!")
            
        if hasattr(d,"__iter__"):
            if hasattr(v,"__iter__"):
                if set(d)==set(v):
                    pruned +=1
                    continue
        u_ret.add(a)
            
    print("Pruned "+ str(pruned) + " unaries")

    pruned = 0
    for d,a in b_next:
        v = a.vals()
            
        if v is None:
            pruned += 1
            continue
        elif len(v) == 0:
            pruned += 1
            continue
            
        if Atom(2004.0) in v and len(v) == 1:
            v_prods.add(a)
            print("2004!")
            
        if hasattr(d,"__iter__"):
            if hasattr(v,"__iter__"):
                if set(d)==set(v):
                    pruned +=1
                    continue

        b_ret.add(a)
    
    print("Pruned "+ str(pruned) + " binaries")
    return u_ret,b_ret,v_prods


u_,b_ = u,b
v_prods = set()
for i in range(3):
    print("Iteration " + str(i))
    u_, b_,v_prods = transition(u_,b_,v_prods)
    print("")
    
for d in v_prods:
    print(d)
# Out:
# Iteration 0
# Starting with 2 unaries
# Starting with 6 binaries
# Generated 46 unaries
# Generated 42 binaries
# Pruned 32 unaries
# Pruned 30 binaries
#
# Iteration 1
# Starting with 16 unaries
# Starting with 18 binaries
# Generated 1392 unaries
# Generated 342 binaries
# Pruned 740 unaries
# Pruned 210 binaries
#
# Iteration 2
# Starting with 668 unaries
# Starting with 138 binaries
# Generated 1169668 unaries
# Generated 19182 binaries
# 2004!
# 2004!
# 2004!
# 2004!
# 2004!
# 2004!
# 2004!
# 2004!
# 2004!
# 2004!
# 2004!
# 2004!
# 2004!
# 2004!
# 2004!
# 2004!
# 2004!
# 2004!
# 2004!
# 2004!
# 2004!
# 2004!
# 2004!
# 2004!
# 2004!
# 2004!
# 2004!
# 2004!
# 2004!
# 2004!
# 2004!
# 2004!
# 2004!
# 2004!
# 2004!
# 2004!
# 2004!
# 2004!
# 2004!
# 2004!
# 2004!
# 2004!
# 2004!
# 2004!
# 2004!
# 2004!
# 2004!
# 2004!
# 2004!
# 2004!
# 2004!
# 2004!
# 2004!
# 2004!
# 2004!
# 2004!
# 2004!
# 2004!
# 2004!
# 2004!
# 2004!
# 2004!
# 2004!
# 2004!
# 2004!
# 2004!
# 2004!
# 2004!
# 2004!
# 2004!
# 2004!
# 2004!
# 2004!
# 2004!
# 2004!
# 2004!
# 2004!
# 2004!
# 2004!
# 2004!
# 2004!
# 2004!
# 2004!
# 2004!
# 2004!
# 2004!
# 2004!
# 2004!
# 2004!
# 2004!
# 2004!
# 2004!
# 2004!
# 2004!
# 2004!
# 2004!
# 2004!
# 2004!
# 2004!
# 2004!
# 2004!
# 2004!
# 2004!
# 2004!
# 2004!
# 2004!
# 2004!
# 2004!
# 2004!
# 2004!
# 2004!
# 2004!
# 2004!
# 2004!
# 2004!
# 2004!
# 2004!
# 2004!
# 2004!
# 2004!
# 2004!
# 2004!
# 2004!
# 2004!
# 2004!
# 2004!
# 2004!
# 2004!
# 2004!
# 2004!
# 2004!
# 2004!
# 2004!
# 2004!
# 2004!
# 2004!
# 2004!
# 2004!
# 2004!
# 2004!
# 2004!
# 2004!
# 2004!
# 2004!
# 2004!
# 2004!
# 2004!
# 2004!
# 2004!
# 2004!
# 2004!
# 2004!
# 2004!
# 2004!
# 2004!
# 2004!
# 2004!
# 2004!
# 2004!
# 2004!
# 2004!
# 2004!
# 2004!
# 2004!
# 2004!
# 2004!
# 2004!
# 2004!
# 2004!
# 2004!
# 2004!
# 2004!
# 2004!
# 2004!
# 2004!
# 2004!
# 2004!
# Pruned 431178 unaries
# Pruned 14696 binaries
#
# [JOIN: [CHAIN: R[[PROPERTY: Year]] x R[[PROPERTY: $next]]] x [INTERSECTION: [ARGMIN: [UNARY: $records] [PROPERTY: Nations]] ^ [ARGMIN: [UNARY: $records] [PROPERTY: Nations]]]]
# [JOIN: [CHAIN: R[[PROPERTY: Year]] x R[[PROPERTY: $next]]] x [INTERSECTION: [ARGMIN: [UNARY: $records] [PROPERTY: Nations]] ^ [INTERSECTION: [UNARY: $records] ^ [UNARY: $records]]]]
# [JOIN: [CHAIN: R[[PROPERTY: Year]] x [CHAIN: [PROPERTY: $next] x [PROPERTY: $next]]] x [INTERSECTION: [ARGMAX: [UNARY: $records] [PROPERTY: Year]] ^ [UNION: [ENTITY:Greece] ^ [UNARY: $records]]]]
# [JOIN: [CHAIN: R[[PROPERTY: Year]] x [PROPERTY: $next]] x [ARGMIN: [ARGMAX: [UNARY: $records] [PROPERTY: Nations]] [PROPERTY: $index]]]
# [JOIN: [CHAIN: R[[PROPERTY: Year]] x R[[PROPERTY: $next]]] x [INTERSECTION: [UNION: [ENTITY:Greece] ^ [UNARY: $records]] ^ [ARGMIN: [UNARY: $records] [PROPERTY: Nations]]]]
# [JOIN: [CHAIN: R[[PROPERTY: Year]] x [CHAIN: [PROPERTY: $next] x [PROPERTY: $next]]] x [UNION: [ARGMAX: [UNARY: $records] [PROPERTY: Year]] ^ [COUNT: [ENTITY:Greece]]]]
# [JOIN: [CHAIN: R[[PROPERTY: Year]] x R[[PROPERTY: $next]]] x [ARGMAX: [ARGMIN: [UNARY: $records] [PROPERTY: Nations]] [PROPERTY: Nations]]]
# [JOIN: [CHAIN: R[[PROPERTY: Year]] x [CHAIN: [PROPERTY: $next] x [PROPERTY: $next]]] x [ARGMAX: [UNION: [UNARY: $records] ^ [ENTITY:Greece]] [PROPERTY: Year]]]
# [JOIN: [CHAIN: R[[PROPERTY: Year]] x R[[PROPERTY: $next]]] x [UNION: [ENTITY:Greece] ^ [ARGMIN: [UNARY: $records] [PROPERTY: Nations]]]]
# [JOIN: [CHAIN: R[[PROPERTY: Year]] x [CHAIN: [PROPERTY: $next] x [PROPERTY: $next]]] x [INTERSECTION: [ARGMAX: [UNARY: $records] [PROPERTY: Year]] ^ [UNION: [UNARY: $records] ^ [UNARY: $records]]]]
# [JOIN: R[[PROPERTY: Year]] x [ARGMAX: [JOIN: [PROPERTY: Country] x [ENTITY:Greece]] [CHAIN: [PROPERTY: $next] x [PROPERTY: Nations]]]]
# [JOIN: [CHAIN: R[[PROPERTY: Year]] x [CHAIN: [PROPERTY: $next] x [PROPERTY: $next]]] x [INTERSECTION: [ARGMAX: [UNARY: $records] [PROPERTY: Year]] ^ [ARGMAX: [UNARY: $records] [PROPERTY: Year]]]]
# [JOIN: [CHAIN: R[[PROPERTY: Year]] x [CHAIN: [PROPERTY: $next] x [PROPERTY: $next]]] x [INTERSECTION: [ARGMAX: [UNARY: $records] [PROPERTY: Year]] ^ [JOIN: [PROPERTY: $next] x [UNARY: $records]]]]
# [JOIN: [CHAIN: R[[PROPERTY: Year]] x [CHAIN: [PROPERTY: $next] x [PROPERTY: $next]]] x [UNION: [ARGMAX: [UNARY: $records] [PROPERTY: Year]] ^ [ARGMIN: [UNARY: $records] [PROPERTY: Year]]]]
# [JOIN: [CHAIN: R[[PROPERTY: Year]] x R[[PROPERTY: $next]]] x [INTERSECTION: [ARGMIN: [UNARY: $records] [PROPERTY: Nations]] ^ [UNARY: $records]]]
# [JOIN: [CHAIN: R[[PROPERTY: Year]] x [CHAIN: [PROPERTY: $next] x [PROPERTY: $next]]] x [INTERSECTION: [ARGMAX: [UNARY: $records] [PROPERTY: Year]] ^ [UNION: [UNARY: $records] ^ [ENTITY:Greece]]]]
# [ARGMAX: [JOIN: R[[PROPERTY: Year]] x [JOIN: [PROPERTY: Country] x [ENTITY:Greece]]] [CHAIN: R[[PROPERTY: Year]] x [PROPERTY: $index]]]
# [JOIN: [CHAIN: R[[PROPERTY: Year]] x R[[PROPERTY: $next]]] x [UNION: [ARGMIN: [UNARY: $records] [PROPERTY: Nations]] ^ [ARGMAX: [UNARY: $records] [PROPERTY: Year]]]]
# [JOIN: [CHAIN: R[[PROPERTY: Year]] x R[[PROPERTY: $next]]] x [INTERSECTION: [ARGMIN: [UNARY: $records] [PROPERTY: Nations]] ^ [UNION: [ENTITY:Greece] ^ [UNARY: $records]]]]
# [JOIN: [CHAIN: R[[PROPERTY: Year]] x R[[PROPERTY: $next]]] x [INTERSECTION: [ARGMIN: [UNARY: $records] [PROPERTY: Nations]] ^ [UNION: [UNARY: $records] ^ [UNARY: $records]]]]
# [JOIN: [CHAIN: R[[PROPERTY: Year]] x [CHAIN: [PROPERTY: $next] x [PROPERTY: $next]]] x [ARGMAX: [UNION: [ENTITY:Greece] ^ [UNARY: $records]] [PROPERTY: Year]]]
# [JOIN: [CHAIN: R[[PROPERTY: Year]] x R[[PROPERTY: $next]]] x [INTERSECTION: [ARGMIN: [UNARY: $records] [PROPERTY: Nations]] ^ [JOIN: [PROPERTY: $next] x [UNARY: $records]]]]
# [JOIN: [CHAIN: R[[PROPERTY: Year]] x [CHAIN: [PROPERTY: $next] x [PROPERTY: $next]]] x [ARGMAX: [UNARY: $records] [PROPERTY: Year]]]
# [ARGMAX: [JOIN: R[[PROPERTY: Year]] x [JOIN: [PROPERTY: Country] x [ENTITY:Greece]]] [CHAIN: R[[PROPERTY: Year]] x [PROPERTY: Year]]]
# [JOIN: [CHAIN: R[[PROPERTY: Year]] x [CHAIN: [PROPERTY: $next] x [PROPERTY: $next]]] x [ARGMIN: [ARGMAX: [UNARY: $records] [PROPERTY: Year]] [PROPERTY: Year]]]
# [JOIN: [CHAIN: R[[PROPERTY: Year]] x [CHAIN: [PROPERTY: $next] x [PROPERTY: $next]]] x [ARGMAX: [UNION: [ENTITY:Greece] ^ [UNARY: $records]] [CHAIN: [PROPERTY: $next] x [PROPERTY: $index]]]]
# [ARGMAX: [JOIN: R[[PROPERTY: Year]] x [JOIN: [PROPERTY: Country] x [ENTITY:Greece]]] [CHAIN: R[[PROPERTY: Year]] x [CHAIN: [PROPERTY: $next] x [PROPERTY: $index]]]]
# [JOIN: [CHAIN: R[[PROPERTY: Year]] x R[[PROPERTY: $next]]] x [INTERSECTION: [ARGMIN: [UNARY: $records] [PROPERTY: Nations]] ^ [UNION: [UNARY: $records] ^ [ENTITY:Greece]]]]
# [JOIN: [CHAIN: R[[PROPERTY: Year]] x [CHAIN: [PROPERTY: $next] x [PROPERTY: $next]]] x [INTERSECTION: [UNION: [UNARY: $records] ^ [ENTITY:Greece]] ^ [ARGMAX: [UNARY: $records] [PROPERTY: Year]]]]
# [JOIN: R[[CHAIN: [PROPERTY: $next] x [PROPERTY: Year]]] x [ARGMAX: [ARGMIN: [UNARY: $records] [PROPERTY: Nations]] [CHAIN: [PROPERTY: $next] x [PROPERTY: $index]]]]
# [ARGMAX: [JOIN: R[[PROPERTY: Year]] x [JOIN: [PROPERTY: Country] x [ENTITY:Greece]]] [CHAIN: R[[PROPERTY: Year]] x [CHAIN: [PROPERTY: $next] x [PROPERTY: Year]]]]
# [JOIN: R[[CHAIN: [PROPERTY: $next] x [PROPERTY: Year]]] x [UNION: [ARGMIN: [UNARY: $records] [PROPERTY: Nations]] ^ [ARGMIN: [UNARY: $records] [PROPERTY: Nations]]]]
# [JOIN: R[[CHAIN: [PROPERTY: $next] x [PROPERTY: Year]]] x [UNION: [COUNT: [UNARY: $records]] ^ [ARGMIN: [UNARY: $records] [PROPERTY: Nations]]]]
# [JOIN: [CHAIN: R[[PROPERTY: Year]] x [CHAIN: [PROPERTY: $next] x [PROPERTY: $next]]] x [ARGMAX: [ARGMAX: [UNARY: $records] [PROPERTY: Year]] [PROPERTY: Nations]]]
# [JOIN: [CHAIN: R[[PROPERTY: Year]] x [CHAIN: [PROPERTY: $next] x [PROPERTY: $next]]] x [ARGMAX: [ARGMAX: [UNARY: $records] [PROPERTY: Year]] [PROPERTY: $index]]]
# [JOIN: R[[PROPERTY: Year]] x [JOIN: R[[PROPERTY: $next]] x [ARGMIN: [UNARY: $records] [PROPERTY: Nations]]]]
# [JOIN: [CHAIN: R[[PROPERTY: Year]] x R[[PROPERTY: $next]]] x [INTERSECTION: [INTERSECTION: [UNARY: $records] ^ [UNARY: $records]] ^ [ARGMIN: [UNARY: $records] [PROPERTY: Nations]]]]
# [JOIN: R[[PROPERTY: Year]] x [ARGMAX: [JOIN: [PROPERTY: Country] x [ENTITY:Greece]] [PROPERTY: Nations]]]
# [JOIN: [CHAIN: R[[PROPERTY: Year]] x [PROPERTY: $next]] x [ARGMIN: [ARGMAX: [UNARY: $records] [PROPERTY: Nations]] [CHAIN: [PROPERTY: $next] x [PROPERTY: $index]]]]
# [JOIN: [CHAIN: R[[PROPERTY: Year]] x [CHAIN: [PROPERTY: $next] x [PROPERTY: $next]]] x [ARGMIN: [ARGMAX: [UNARY: $records] [PROPERTY: Year]] [PROPERTY: $index]]]
# [JOIN: [CHAIN: R[[PROPERTY: Year]] x [PROPERTY: $next]] x [JOIN: [CHAIN: [PROPERTY: $next] x [PROPERTY: $next]] x [ARGMAX: [UNARY: $records] [PROPERTY: $index]]]]
# [JOIN: [CHAIN: R[[PROPERTY: Year]] x R[[PROPERTY: $next]]] x [UNION: [ARGMIN: [UNARY: $records] [PROPERTY: Nations]] ^ [ENTITY:Greece]]]
# [JOIN: [CHAIN: R[[PROPERTY: Year]] x R[[PROPERTY: $next]]] x [ARGMIN: [UNION: [ENTITY:Greece] ^ [UNARY: $records]] [PROPERTY: Nations]]]
# [JOIN: [CHAIN: R[[PROPERTY: Year]] x R[[PROPERTY: $next]]] x [JOIN: R[[PROPERTY: $next]] x [ARGMIN: [UNARY: $records] [PROPERTY: Year]]]]
# [JOIN: [CHAIN: R[[PROPERTY: Year]] x [CHAIN: [PROPERTY: $next] x [PROPERTY: $next]]] x [ARGMAX: [JOIN: [PROPERTY: $next] x [UNARY: $records]] [PROPERTY: $index]]]
# [ARGMAX: [JOIN: R[[PROPERTY: Year]] x [JOIN: [PROPERTY: Country] x [ENTITY:Greece]]] [CHAIN: R[[PROPERTY: Year]] x [CHAIN: [PROPERTY: $next] x [PROPERTY: Nations]]]]
# [JOIN: [CHAIN: R[[PROPERTY: Year]] x [CHAIN: [PROPERTY: $next] x [PROPERTY: $next]]] x [ARGMIN: [ARGMAX: [UNARY: $records] [PROPERTY: Year]] [PROPERTY: Nations]]]
# [JOIN: R[[CHAIN: [PROPERTY: $next] x [PROPERTY: Year]]] x [ARGMIN: [UNARY: $records] [PROPERTY: Nations]]]
# [JOIN: [CHAIN: R[[PROPERTY: Year]] x [CHAIN: [PROPERTY: $next] x [PROPERTY: $next]]] x [ARGMAX: [INTERSECTION: [UNARY: $records] ^ [UNARY: $records]] [PROPERTY: Year]]]
# [JOIN: [CHAIN: R[[PROPERTY: Year]] x R[[PROPERTY: $next]]] x [UNION: [ARGMAX: [UNARY: $records] [PROPERTY: $index]] ^ [ARGMIN: [UNARY: $records] [PROPERTY: Nations]]]]
# [JOIN: [CHAIN: R[[PROPERTY: Year]] x [CHAIN: [PROPERTY: $next] x [PROPERTY: $next]]] x [INTERSECTION: [INTERSECTION: [UNARY: $records] ^ [UNARY: $records]] ^ [ARGMAX: [UNARY: $records] [PROPERTY: Year]]]]
# [JOIN: R[[CHAIN: [PROPERTY: $next] x [PROPERTY: Year]]] x [INTERSECTION: [UNION: [UNARY: $records] ^ [ENTITY:Greece]] ^ [ARGMIN: [UNARY: $records] [PROPERTY: Nations]]]]
# [JOIN: [CHAIN: R[[PROPERTY: Year]] x [CHAIN: [PROPERTY: $next] x [PROPERTY: $next]]] x [INTERSECTION: [UNARY: $records] ^ [ARGMAX: [UNARY: $records] [PROPERTY: Year]]]]
# [JOIN: [CHAIN: R[[PROPERTY: Year]] x [PROPERTY: $next]] x [ARGMAX: [ARGMAX: [UNARY: $records] [PROPERTY: Nations]] [CHAIN: [PROPERTY: $next] x [PROPERTY: Year]]]]
# [JOIN: [CHAIN: R[[PROPERTY: Year]] x R[[PROPERTY: $next]]] x [INTERSECTION: [JOIN: [PROPERTY: $next] x [UNARY: $records]] ^ [ARGMIN: [UNARY: $records] [PROPERTY: Nations]]]]
# [JOIN: [CHAIN: R[[PROPERTY: Year]] x [CHAIN: [PROPERTY: $next] x [PROPERTY: $next]]] x [ARGMIN: [ARGMAX: [UNARY: $records] [PROPERTY: Year]] [CHAIN: [PROPERTY: $next] x [PROPERTY: $index]]]]
# [JOIN: [CHAIN: R[[PROPERTY: Year]] x R[[PROPERTY: $next]]] x [UNION: [ARGMIN: [UNARY: $records] [PROPERTY: Nations]] ^ [COUNT: [UNARY: $records]]]]
# [JOIN: [CHAIN: R[[PROPERTY: Year]] x [CHAIN: [PROPERTY: $next] x [PROPERTY: $next]]] x [UNION: [COUNT: [ENTITY:Greece]] ^ [ARGMAX: [UNARY: $records] [PROPERTY: Year]]]]
# [JOIN: [CHAIN: R[[PROPERTY: Year]] x [CHAIN: [PROPERTY: $next] x [PROPERTY: $next]]] x [ARGMAX: [JOIN: [PROPERTY: $next] x [UNARY: $records]] [PROPERTY: Year]]]
# [JOIN: R[[CHAIN: [PROPERTY: $next] x [PROPERTY: Year]]] x [UNION: [ARGMIN: [UNARY: $records] [PROPERTY: Nations]] ^ [ARGMAX: [UNARY: $records] [PROPERTY: $index]]]]
# [JOIN: R[[PROPERTY: Year]] x [JOIN: [CHAIN: [PROPERTY: $next] x [PROPERTY: $next]] x [ARGMAX: [UNARY: $records] [PROPERTY: Year]]]]
# [JOIN: R[[CHAIN: [PROPERTY: $next] x [PROPERTY: Year]]] x [ARGMAX: [ARGMIN: [UNARY: $records] [PROPERTY: Nations]] [CHAIN: [PROPERTY: $next] x [PROPERTY: Year]]]]
# [JOIN: R[[CHAIN: [PROPERTY: $next] x [PROPERTY: Year]]] x [ARGMIN: [JOIN: [PROPERTY: $next] x [UNARY: $records]] [PROPERTY: Nations]]]
# [JOIN: [CHAIN: R[[PROPERTY: Year]] x R[[PROPERTY: $next]]] x [ARGMIN: [UNION: [UNARY: $records] ^ [ENTITY:Greece]] [PROPERTY: Nations]]]
# [JOIN: [CHAIN: R[[PROPERTY: Year]] x [PROPERTY: $next]] x [ARGMIN: [ARGMAX: [UNARY: $records] [PROPERTY: Nations]] [CHAIN: [PROPERTY: $next] x [PROPERTY: Nations]]]]
# [JOIN: [CHAIN: R[[PROPERTY: Year]] x R[[PROPERTY: $next]]] x [INTERSECTION: [UNION: [UNARY: $records] ^ [UNARY: $records]] ^ [ARGMIN: [UNARY: $records] [PROPERTY: Nations]]]]
# [JOIN: [CHAIN: R[[PROPERTY: Year]] x [CHAIN: [PROPERTY: $next] x [PROPERTY: $next]]] x [ARGMAX: [JOIN: [PROPERTY: $next] x [UNARY: $records]] [CHAIN: [PROPERTY: $next] x [PROPERTY: $index]]]]
# [JOIN: [CHAIN: R[[PROPERTY: Year]] x [CHAIN: [PROPERTY: $next] x [PROPERTY: $next]]] x [INTERSECTION: [JOIN: [PROPERTY: $next] x [UNARY: $records]] ^ [ARGMAX: [UNARY: $records] [PROPERTY: Year]]]]
# [JOIN: R[[CHAIN: [PROPERTY: $next] x [PROPERTY: Year]]] x [ARGMIN: [INTERSECTION: [UNARY: $records] ^ [UNARY: $records]] [PROPERTY: Nations]]]
# [JOIN: R[[CHAIN: [PROPERTY: $next] x [PROPERTY: Year]]] x [JOIN: [PROPERTY: $next] x [JOIN: [PROPERTY: Country] x [ENTITY:Greece]]]]
# [JOIN: [CHAIN: R[[PROPERTY: Year]] x [PROPERTY: $next]] x [ARGMAX: [ARGMAX: [UNARY: $records] [PROPERTY: Nations]] [CHAIN: [PROPERTY: $next] x [PROPERTY: Nations]]]]
# [ARGMAX: [JOIN: R[[PROPERTY: Year]] x [JOIN: [PROPERTY: Country] x [ENTITY:Greece]]] [CHAIN: R[[PROPERTY: Year]] x [PROPERTY: Nations]]]
# [JOIN: [CHAIN: R[[PROPERTY: Year]] x [PROPERTY: $next]] x [ARGMAX: [UNION: [UNARY: $records] ^ [ENTITY:Greece]] [CHAIN: [PROPERTY: $next] x [PROPERTY: Year]]]]
# [JOIN: R[[CHAIN: [PROPERTY: $next] x [PROPERTY: Year]]] x [INTERSECTION: [UNARY: $records] ^ [ARGMIN: [UNARY: $records] [PROPERTY: Nations]]]]
# [JOIN: [CHAIN: R[[PROPERTY: Year]] x R[[PROPERTY: $next]]] x [JOIN: [CHAIN: [PROPERTY: $next] x [PROPERTY: Country]] x [ENTITY:Greece]]]
# [JOIN: [CHAIN: R[[PROPERTY: Year]] x R[[PROPERTY: $next]]] x [ARGMAX: [ARGMIN: [UNARY: $records] [PROPERTY: Nations]] [CHAIN: [PROPERTY: $next] x [PROPERTY: $index]]]]
# [JOIN: [CHAIN: R[[PROPERTY: Year]] x [CHAIN: [PROPERTY: $next] x [PROPERTY: $next]]] x [ARGMAX: [ARGMAX: [UNARY: $records] [PROPERTY: Nations]] [PROPERTY: $index]]]
# [JOIN: R[[CHAIN: [PROPERTY: $next] x [PROPERTY: Year]]] x [UNION: [COUNT: [ENTITY:Greece]] ^ [ARGMIN: [UNARY: $records] [PROPERTY: Nations]]]]
# [JOIN: [CHAIN: R[[PROPERTY: Year]] x R[[PROPERTY: $next]]] x [UNION: [COUNT: [UNARY: $records]] ^ [ARGMIN: [UNARY: $records] [PROPERTY: Nations]]]]
# [JOIN: [CHAIN: R[[PROPERTY: Year]] x R[[PROPERTY: $next]]] x [UNION: [ARGMIN: [UNARY: $records] [PROPERTY: Nations]] ^ [ARGMIN: [UNARY: $records] [PROPERTY: Nations]]]]
# [JOIN: [CHAIN: R[[PROPERTY: Year]] x R[[PROPERTY: $next]]] x [JOIN: [CHAIN: [PROPERTY: $next] x [PROPERTY: Country]] x [UNION: [ENTITY:Greece] ^ [UNARY: $records]]]]
# [JOIN: [CHAIN: R[[PROPERTY: Year]] x [CHAIN: [PROPERTY: $next] x [PROPERTY: $next]]] x [ARGMAX: [INTERSECTION: [UNARY: $records] ^ [UNARY: $records]] [CHAIN: [PROPERTY: $next] x [PROPERTY: $index]]]]
# [JOIN: R[[CHAIN: [PROPERTY: $next] x [PROPERTY: Year]]] x [ARGMIN: [UNION: [UNARY: $records] ^ [UNARY: $records]] [PROPERTY: Nations]]]
# [JOIN: R[[CHAIN: [PROPERTY: $next] x [PROPERTY: Year]]] x [ARGMIN: [UNARY: $records] [PROPERTY: Nations]]]
# [JOIN: R[[CHAIN: [PROPERTY: $next] x [PROPERTY: Year]]] x [UNION: [ARGMIN: [UNARY: $records] [PROPERTY: Nations]] ^ [COUNT: [ENTITY:Greece]]]]
# [JOIN: [CHAIN: R[[PROPERTY: Year]] x R[[PROPERTY: $next]]] x [JOIN: [CHAIN: [PROPERTY: $next] x [PROPERTY: Country]] x [UNION: [UNARY: $records] ^ [ENTITY:Greece]]]]
# [JOIN: [CHAIN: R[[PROPERTY: Year]] x [PROPERTY: $next]] x [ARGMAX: [INTERSECTION: [UNARY: $records] ^ [UNARY: $records]] [CHAIN: [PROPERTY: $next] x [PROPERTY: Year]]]]
# [JOIN: [CHAIN: R[[PROPERTY: Year]] x [CHAIN: [PROPERTY: $next] x [PROPERTY: $next]]] x [ARGMAX: [ARGMAX: [UNARY: $records] [PROPERTY: Nations]] [PROPERTY: Year]]]
# [JOIN: [CHAIN: R[[PROPERTY: Year]] x [CHAIN: [PROPERTY: $next] x [PROPERTY: $next]]] x [INTERSECTION: [ARGMAX: [UNARY: $records] [PROPERTY: Nations]] ^ [ARGMAX: [UNARY: $records] [PROPERTY: Year]]]]
# [JOIN: [CHAIN: R[[PROPERTY: Year]] x R[[PROPERTY: $next]]] x [ARGMIN: [UNARY: $records] [PROPERTY: Nations]]]
# [JOIN: R[[PROPERTY: Year]] x [ARGMAX: [JOIN: [PROPERTY: Country] x [ENTITY:Greece]] [CHAIN: [PROPERTY: $next] x [PROPERTY: Year]]]]
# [JOIN: [CHAIN: R[[PROPERTY: Year]] x [CHAIN: [PROPERTY: $next] x [PROPERTY: $next]]] x [UNION: [COUNT: [UNARY: $records]] ^ [ARGMAX: [UNARY: $records] [PROPERTY: Year]]]]
# [JOIN: R[[CHAIN: [PROPERTY: $next] x [PROPERTY: Year]]] x [ARGMAX: [ARGMIN: [UNARY: $records] [PROPERTY: Nations]] [PROPERTY: $index]]]
# [JOIN: R[[CHAIN: [PROPERTY: $next] x [PROPERTY: Year]]] x [ARGMIN: [ARGMIN: [UNARY: $records] [PROPERTY: Nations]] [PROPERTY: $index]]]
# [JOIN: [CHAIN: R[[PROPERTY: Year]] x [PROPERTY: $next]] x [ARGMIN: [ARGMAX: [UNARY: $records] [PROPERTY: Nations]] [PROPERTY: Year]]]
# [JOIN: [CHAIN: R[[PROPERTY: Year]] x R[[PROPERTY: $next]]] x [INTERSECTION: [UNION: [UNARY: $records] ^ [ENTITY:Greece]] ^ [ARGMIN: [UNARY: $records] [PROPERTY: Nations]]]]
# [JOIN: [CHAIN: R[[PROPERTY: Year]] x [CHAIN: [PROPERTY: $next] x [PROPERTY: $next]]] x [ARGMAX: [UNARY: $records] [PROPERTY: Year]]]
# [JOIN: [CHAIN: R[[PROPERTY: Year]] x [PROPERTY: $next]] x [ARGMAX: [JOIN: [PROPERTY: $next] x [UNARY: $records]] [CHAIN: [PROPERTY: $next] x [PROPERTY: Year]]]]
# [JOIN: [CHAIN: R[[PROPERTY: Year]] x [CHAIN: [PROPERTY: $next] x [PROPERTY: $next]]] x [UNION: [ARGMAX: [UNARY: $records] [PROPERTY: Year]] ^ [ARGMAX: [UNARY: $records] [PROPERTY: Year]]]]
# [JOIN: R[[CHAIN: [PROPERTY: $next] x [PROPERTY: Year]]] x [ARGMIN: [UNION: [UNARY: $records] ^ [ENTITY:Greece]] [PROPERTY: Nations]]]
# [JOIN: [CHAIN: R[[PROPERTY: Year]] x [CHAIN: [PROPERTY: $next] x [PROPERTY: $next]]] x [ARGMAX: [UNION: [UNARY: $records] ^ [ENTITY:Greece]] [CHAIN: [PROPERTY: $next] x [PROPERTY: $index]]]]
# [JOIN: [CHAIN: R[[PROPERTY: Year]] x [CHAIN: [PROPERTY: $next] x [PROPERTY: $next]]] x [ARGMAX: [UNION: [UNARY: $records] ^ [UNARY: $records]] [PROPERTY: Year]]]
# [JOIN: [CHAIN: R[[PROPERTY: Year]] x [CHAIN: [PROPERTY: $next] x [PROPERTY: $next]]] x [ARGMAX: [ARGMAX: [UNARY: $records] [PROPERTY: Nations]] [CHAIN: [PROPERTY: $next] x [PROPERTY: $index]]]]
# [JOIN: R[[CHAIN: [PROPERTY: $next] x [PROPERTY: Year]]] x [INTERSECTION: [UNION: [UNARY: $records] ^ [UNARY: $records]] ^ [ARGMIN: [UNARY: $records] [PROPERTY: Nations]]]]
# [JOIN: [CHAIN: R[[PROPERTY: Year]] x R[[PROPERTY: $next]]] x [UNION: [ARGMIN: [UNARY: $records] [PROPERTY: Nations]] ^ [ARGMAX: [UNARY: $records] [PROPERTY: $index]]]]
# [JOIN: R[[CHAIN: [PROPERTY: $next] x [PROPERTY: Year]]] x [ARGMIN: [ARGMIN: [UNARY: $records] [PROPERTY: Nations]] [PROPERTY: Year]]]
# [JOIN: [CHAIN: R[[PROPERTY: Year]] x R[[PROPERTY: $next]]] x [ARGMIN: [ARGMIN: [UNARY: $records] [PROPERTY: Nations]] [CHAIN: [PROPERTY: $next] x [PROPERTY: Nations]]]]
# [JOIN: [CHAIN: R[[PROPERTY: Year]] x [CHAIN: [PROPERTY: $next] x [PROPERTY: $next]]] x [ARGMAX: [UNION: [UNARY: $records] ^ [UNARY: $records]] [CHAIN: [PROPERTY: $next] x [PROPERTY: $index]]]]
# [JOIN: [CHAIN: R[[PROPERTY: Year]] x R[[PROPERTY: $next]]] x [ARGMAX: [ARGMIN: [UNARY: $records] [PROPERTY: Nations]] [CHAIN: [PROPERTY: $next] x [PROPERTY: Year]]]]
# [JOIN: [CHAIN: R[[PROPERTY: Year]] x [CHAIN: [PROPERTY: $next] x [PROPERTY: $next]]] x [ARGMAX: [UNARY: $records] [CHAIN: [PROPERTY: $next] x [PROPERTY: $index]]]]
# [JOIN: [CHAIN: R[[PROPERTY: Year]] x R[[PROPERTY: $next]]] x [ARGMIN: [JOIN: [PROPERTY: $next] x [UNARY: $records]] [PROPERTY: Nations]]]
# [JOIN: R[[CHAIN: [PROPERTY: $next] x [PROPERTY: Year]]] x [JOIN: [CHAIN: [PROPERTY: $next] x [PROPERTY: Country]] x [ENTITY:Greece]]]
# [JOIN: [CHAIN: R[[PROPERTY: Year]] x [CHAIN: [PROPERTY: $next] x [PROPERTY: $next]]] x [UNION: [ARGMAX: [UNARY: $records] [PROPERTY: Year]] ^ [ARGMIN: [UNARY: $records] [PROPERTY: $index]]]]
# [JOIN: [CHAIN: R[[PROPERTY: Year]] x [CHAIN: [PROPERTY: $next] x [PROPERTY: $next]]] x [UNION: [ENTITY:Greece] ^ [ARGMAX: [UNARY: $records] [PROPERTY: Year]]]]
# [JOIN: R[[CHAIN: [PROPERTY: $next] x [PROPERTY: Year]]] x [ARGMAX: [ARGMIN: [UNARY: $records] [PROPERTY: Nations]] [PROPERTY: Year]]]
# [JOIN: [CHAIN: R[[PROPERTY: Year]] x [CHAIN: [PROPERTY: $next] x [PROPERTY: $next]]] x [ARGMAX: [ARGMAX: [UNARY: $records] [PROPERTY: Year]] [CHAIN: [PROPERTY: $next] x [PROPERTY: $index]]]]
# [JOIN: R[[CHAIN: [PROPERTY: $next] x [PROPERTY: Year]]] x [ARGMIN: [ARGMIN: [UNARY: $records] [PROPERTY: Nations]] [CHAIN: [PROPERTY: $next] x [PROPERTY: $index]]]]
# [JOIN: [CHAIN: R[[PROPERTY: Year]] x [CHAIN: [PROPERTY: $next] x [PROPERTY: $next]]] x [INTERSECTION: [UNION: [ENTITY:Greece] ^ [UNARY: $records]] ^ [ARGMAX: [UNARY: $records] [PROPERTY: Year]]]]
# [JOIN: [CHAIN: R[[PROPERTY: Year]] x [PROPERTY: $next]] x [JOIN: [PROPERTY: $next] x [ARGMAX: [UNARY: $records] [PROPERTY: Year]]]]
# [JOIN: [CHAIN: R[[PROPERTY: Year]] x R[[PROPERTY: $next]]] x [ARGMIN: [INTERSECTION: [UNARY: $records] ^ [UNARY: $records]] [PROPERTY: Nations]]]
# [JOIN: R[[CHAIN: [PROPERTY: $next] x [PROPERTY: Year]]] x [ARGMIN: [ARGMIN: [UNARY: $records] [PROPERTY: Nations]] [PROPERTY: Nations]]]
# [JOIN: R[[CHAIN: [PROPERTY: $next] x [PROPERTY: Year]]] x [JOIN: [CHAIN: [PROPERTY: $next] x [PROPERTY: Country]] x [UNION: [ENTITY:Greece] ^ [UNARY: $records]]]]
# [JOIN: [CHAIN: R[[PROPERTY: Year]] x R[[PROPERTY: $next]]] x [JOIN: [PROPERTY: $next] x [JOIN: [PROPERTY: Country] x [ENTITY:Greece]]]]
# [JOIN: [CHAIN: R[[PROPERTY: Year]] x R[[PROPERTY: $next]]] x [UNION: [ARGMAX: [UNARY: $records] [PROPERTY: Year]] ^ [ARGMIN: [UNARY: $records] [PROPERTY: Nations]]]]
# [JOIN: [CHAIN: R[[PROPERTY: Year]] x R[[PROPERTY: $next]]] x [ARGMAX: [ARGMIN: [UNARY: $records] [PROPERTY: Nations]] [CHAIN: [PROPERTY: $next] x [PROPERTY: Nations]]]]
# [JOIN: [CHAIN: R[[PROPERTY: Year]] x [CHAIN: [PROPERTY: $next] x [PROPERTY: $next]]] x [UNION: [ARGMAX: [UNARY: $records] [PROPERTY: Year]] ^ [COUNT: [UNARY: $records]]]]
# [JOIN: [CHAIN: R[[PROPERTY: Year]] x R[[PROPERTY: $next]]] x [INTERSECTION: [UNARY: $records] ^ [ARGMIN: [UNARY: $records] [PROPERTY: Nations]]]]
# [JOIN: [CHAIN: R[[PROPERTY: Year]] x R[[PROPERTY: $next]]] x [UNION: [COUNT: [ENTITY:Greece]] ^ [ARGMIN: [UNARY: $records] [PROPERTY: Nations]]]]
# [JOIN: R[[CHAIN: [PROPERTY: $next] x [PROPERTY: Year]]] x [JOIN: [CHAIN: [PROPERTY: $next] x [PROPERTY: Country]] x [UNION: [UNARY: $records] ^ [ENTITY:Greece]]]]
# [JOIN: R[[CHAIN: [PROPERTY: $next] x [PROPERTY: Year]]] x [ARGMIN: [ARGMIN: [UNARY: $records] [PROPERTY: Nations]] [CHAIN: [PROPERTY: $next] x [PROPERTY: Year]]]]
# [JOIN: R[[PROPERTY: Year]] x [ARGMAX: [JOIN: [PROPERTY: Country] x [ENTITY:Greece]] [PROPERTY: $index]]]
# [JOIN: [CHAIN: R[[PROPERTY: Year]] x R[[PROPERTY: $next]]] x [ARGMIN: [UNION: [UNARY: $records] ^ [UNARY: $records]] [PROPERTY: Nations]]]
# [JOIN: R[[CHAIN: [PROPERTY: $next] x [PROPERTY: Year]]] x [INTERSECTION: [ARGMIN: [UNARY: $records] [PROPERTY: Nations]] ^ [ARGMIN: [UNARY: $records] [PROPERTY: Nations]]]]
# [JOIN: [CHAIN: R[[PROPERTY: Year]] x R[[PROPERTY: $next]]] x [ARGMIN: [UNARY: $records] [PROPERTY: Nations]]]
# [JOIN: [CHAIN: R[[PROPERTY: Year]] x R[[PROPERTY: $next]]] x [UNION: [ARGMIN: [UNARY: $records] [PROPERTY: Nations]] ^ [COUNT: [ENTITY:Greece]]]]
# [JOIN: R[[CHAIN: [PROPERTY: $next] x [PROPERTY: Year]]] x [INTERSECTION: [ARGMIN: [UNARY: $records] [PROPERTY: Nations]] ^ [INTERSECTION: [UNARY: $records] ^ [UNARY: $records]]]]
# [JOIN: R[[CHAIN: [PROPERTY: $next] x [PROPERTY: Year]]] x [INTERSECTION: [UNION: [ENTITY:Greece] ^ [UNARY: $records]] ^ [ARGMIN: [UNARY: $records] [PROPERTY: Nations]]]]
# [JOIN: R[[CHAIN: [PROPERTY: $next] x [PROPERTY: Year]]] x [ARGMAX: [ARGMIN: [UNARY: $records] [PROPERTY: Nations]] [PROPERTY: Nations]]]
# [JOIN: R[[CHAIN: [PROPERTY: $next] x [PROPERTY: Year]]] x [UNION: [ENTITY:Greece] ^ [ARGMIN: [UNARY: $records] [PROPERTY: Nations]]]]
# [JOIN: [CHAIN: R[[PROPERTY: Year]] x [CHAIN: [PROPERTY: $next] x [PROPERTY: $next]]] x [JOIN: [PROPERTY: $next] x [ARGMAX: [UNARY: $records] [PROPERTY: $index]]]]
# [JOIN: [CHAIN: R[[PROPERTY: Year]] x [PROPERTY: $next]] x [ARGMAX: [UNARY: $records] [CHAIN: [PROPERTY: $next] x [PROPERTY: Year]]]]
# [JOIN: [CHAIN: R[[PROPERTY: Year]] x [PROPERTY: $next]] x [ARGMAX: [UNION: [ENTITY:Greece] ^ [UNARY: $records]] [CHAIN: [PROPERTY: $next] x [PROPERTY: Year]]]]
# [JOIN: [CHAIN: R[[PROPERTY: Year]] x [PROPERTY: $next]] x [ARGMAX: [UNION: [UNARY: $records] ^ [UNARY: $records]] [CHAIN: [PROPERTY: $next] x [PROPERTY: Year]]]]
# [JOIN: R[[CHAIN: [PROPERTY: $next] x [PROPERTY: Year]]] x [INTERSECTION: [ARGMIN: [UNARY: $records] [PROPERTY: Nations]] ^ [UNARY: $records]]]
# [JOIN: [CHAIN: R[[PROPERTY: Year]] x R[[PROPERTY: $next]]] x [ARGMAX: [ARGMIN: [UNARY: $records] [PROPERTY: Nations]] [PROPERTY: $index]]]
# [JOIN: R[[CHAIN: [PROPERTY: $next] x [PROPERTY: Year]]] x [INTERSECTION: [ARGMIN: [UNARY: $records] [PROPERTY: Nations]] ^ [UNION: [ENTITY:Greece] ^ [UNARY: $records]]]]
# [JOIN: R[[CHAIN: [PROPERTY: $next] x [PROPERTY: Year]]] x [UNION: [ARGMIN: [UNARY: $records] [PROPERTY: Nations]] ^ [ARGMAX: [UNARY: $records] [PROPERTY: Year]]]]
# [JOIN: R[[PROPERTY: Year]] x [ARGMAX: [JOIN: [PROPERTY: Country] x [ENTITY:Greece]] [PROPERTY: Year]]]
# [JOIN: R[[CHAIN: [PROPERTY: $next] x [PROPERTY: Year]]] x [ARGMIN: [ARGMIN: [UNARY: $records] [PROPERTY: Nations]] [CHAIN: [PROPERTY: $next] x [PROPERTY: Nations]]]]
# [JOIN: [CHAIN: R[[PROPERTY: Year]] x R[[PROPERTY: $next]]] x [ARGMIN: [ARGMIN: [UNARY: $records] [PROPERTY: Nations]] [PROPERTY: $index]]]
# [JOIN: R[[CHAIN: [PROPERTY: $next] x [PROPERTY: Year]]] x [INTERSECTION: [ARGMIN: [UNARY: $records] [PROPERTY: Nations]] ^ [UNION: [UNARY: $records] ^ [UNARY: $records]]]]
# [JOIN: R[[CHAIN: [PROPERTY: $next] x [PROPERTY: Year]]] x [INTERSECTION: [ARGMIN: [UNARY: $records] [PROPERTY: Nations]] ^ [JOIN: [PROPERTY: $next] x [UNARY: $records]]]]
# [JOIN: R[[CHAIN: [PROPERTY: $next] x [PROPERTY: Year]]] x [INTERSECTION: [ARGMIN: [UNARY: $records] [PROPERTY: Nations]] ^ [UNION: [UNARY: $records] ^ [ENTITY:Greece]]]]
# [JOIN: [CHAIN: R[[PROPERTY: Year]] x [CHAIN: [PROPERTY: $next] x [PROPERTY: $next]]] x [UNION: [ARGMIN: [UNARY: $records] [PROPERTY: Year]] ^ [ARGMAX: [UNARY: $records] [PROPERTY: Year]]]]
# [JOIN: [CHAIN: R[[PROPERTY: Year]] x R[[PROPERTY: $next]]] x [ARGMIN: [ARGMIN: [UNARY: $records] [PROPERTY: Nations]] [PROPERTY: Year]]]
# [JOIN: R[[PROPERTY: Year]] x [ARGMAX: [JOIN: [PROPERTY: Country] x [ENTITY:Greece]] [CHAIN: [PROPERTY: $next] x [PROPERTY: $index]]]]
# [JOIN: R[[CHAIN: [PROPERTY: $next] x [PROPERTY: Year]]] x [UNION: [ARGMAX: [UNARY: $records] [PROPERTY: Year]] ^ [ARGMIN: [UNARY: $records] [PROPERTY: Nations]]]]
# [JOIN: R[[CHAIN: [PROPERTY: $next] x [PROPERTY: Year]]] x [ARGMAX: [ARGMIN: [UNARY: $records] [PROPERTY: Nations]] [CHAIN: [PROPERTY: $next] x [PROPERTY: Nations]]]]
# [JOIN: [CHAIN: R[[PROPERTY: Year]] x [CHAIN: [PROPERTY: $next] x [PROPERTY: $next]]] x [UNION: [ARGMAX: [UNARY: $records] [PROPERTY: Year]] ^ [ENTITY:Greece]]]
# [JOIN: R[[CHAIN: [PROPERTY: $next] x [PROPERTY: Year]]] x [INTERSECTION: [INTERSECTION: [UNARY: $records] ^ [UNARY: $records]] ^ [ARGMIN: [UNARY: $records] [PROPERTY: Nations]]]]
# [JOIN: [CHAIN: R[[PROPERTY: Year]] x R[[PROPERTY: $next]]] x [ARGMAX: [ARGMIN: [UNARY: $records] [PROPERTY: Nations]] [PROPERTY: Year]]]
# [JOIN: [CHAIN: R[[PROPERTY: Year]] x R[[PROPERTY: $next]]] x [ARGMIN: [ARGMIN: [UNARY: $records] [PROPERTY: Nations]] [CHAIN: [PROPERTY: $next] x [PROPERTY: $index]]]]
# [JOIN: R[[CHAIN: [PROPERTY: $next] x [PROPERTY: Year]]] x [UNION: [ARGMIN: [UNARY: $records] [PROPERTY: Nations]] ^ [ENTITY:Greece]]]
# [JOIN: [CHAIN: R[[PROPERTY: Year]] x R[[PROPERTY: $next]]] x [ARGMIN: [ARGMIN: [UNARY: $records] [PROPERTY: Nations]] [PROPERTY: Nations]]]
# [JOIN: [CHAIN: R[[PROPERTY: Year]] x [PROPERTY: $next]] x [ARGMIN: [ARGMAX: [UNARY: $records] [PROPERTY: Nations]] [CHAIN: [PROPERTY: $next] x [PROPERTY: Year]]]]
# [JOIN: R[[CHAIN: [PROPERTY: $next] x [PROPERTY: Year]]] x [ARGMIN: [UNION: [ENTITY:Greece] ^ [UNARY: $records]] [PROPERTY: Nations]]]
# [JOIN: [CHAIN: R[[PROPERTY: Year]] x [CHAIN: [PROPERTY: $next] x [PROPERTY: $next]]] x [INTERSECTION: [UNION: [UNARY: $records] ^ [UNARY: $records]] ^ [ARGMAX: [UNARY: $records] [PROPERTY: Year]]]]
# [JOIN: R[[CHAIN: [PROPERTY: $next] x [PROPERTY: Year]]] x [JOIN: R[[PROPERTY: $next]] x [ARGMIN: [UNARY: $records] [PROPERTY: Year]]]]
# [JOIN: [CHAIN: R[[PROPERTY: Year]] x [CHAIN: [PROPERTY: $next] x [PROPERTY: $next]]] x [UNION: [ARGMIN: [UNARY: $records] [PROPERTY: $index]] ^ [ARGMAX: [UNARY: $records] [PROPERTY: Year]]]]
# [JOIN: R[[CHAIN: [PROPERTY: $next] x [PROPERTY: Year]]] x [UNION: [ARGMAX: [UNARY: $records] [PROPERTY: $index]] ^ [ARGMIN: [UNARY: $records] [PROPERTY: Nations]]]]
# [JOIN: [CHAIN: R[[PROPERTY: Year]] x [CHAIN: [PROPERTY: $next] x [PROPERTY: $next]]] x [ARGMAX: [ARGMAX: [UNARY: $records] [PROPERTY: Year]] [PROPERTY: Year]]]
# [JOIN: R[[CHAIN: [PROPERTY: $next] x [PROPERTY: Year]]] x [INTERSECTION: [JOIN: [PROPERTY: $next] x [UNARY: $records]] ^ [ARGMIN: [UNARY: $records] [PROPERTY: Nations]]]]
# [JOIN: [CHAIN: R[[PROPERTY: Year]] x R[[PROPERTY: $next]]] x [ARGMIN: [ARGMIN: [UNARY: $records] [PROPERTY: Nations]] [CHAIN: [PROPERTY: $next] x [PROPERTY: Year]]]]
# [JOIN: [CHAIN: R[[PROPERTY: Year]] x [CHAIN: [PROPERTY: $next] x [PROPERTY: $next]]] x [INTERSECTION: [ARGMAX: [UNARY: $records] [PROPERTY: Year]] ^ [INTERSECTION: [UNARY: $records] ^ [UNARY: $records]]]]
# [JOIN: R[[CHAIN: [PROPERTY: $next] x [PROPERTY: Year]]] x [UNION: [ARGMIN: [UNARY: $records] [PROPERTY: Nations]] ^ [COUNT: [UNARY: $records]]]]
# [JOIN: [CHAIN: R[[PROPERTY: Year]] x [CHAIN: [PROPERTY: $next] x [PROPERTY: $next]]] x [INTERSECTION: [ARGMAX: [UNARY: $records] [PROPERTY: Year]] ^ [ARGMAX: [UNARY: $records] [PROPERTY: Nations]]]]
# [JOIN: [CHAIN: R[[PROPERTY: Year]] x [CHAIN: [PROPERTY: $next] x [PROPERTY: $next]]] x [INTERSECTION: [ARGMAX: [UNARY: $records] [PROPERTY: Year]] ^ [UNARY: $records]]]

# %%
print([str(a) for a in Join(Reverse(properties[0]), ArgMax(Join(properties[2],Entity("Greece")),index)).vals()])
print(Join(Reverse(properties[0]), ArgMax(Join(properties[2],Entity("Greece")),index)))
# Out:
# ['[ATOM:2004.0]']
# [JOIN: R[[PROPERTY: Year]] x [ARGMAX: [JOIN: [PROPERTY: Country] x [ENTITY:Greece]] [PROPERTY: $index]]]

# %%
table = Table("towns.tsv")


properties = []
for prop in table.read()['header']:
    properties.append(Property(prop))


       
atoms = set()
entities = set()

row_id = 0
last_row = None

next_row = Property("$next")
index = Property("$index")

records = Unary("$records") 

properties.append(next_row)
properties.append(index)

for row in table.read()['rows']:
    r = Record("$"+str(row_id))
    
    index.add(r,Atom(row_id))
    
    col_id = 0 
    for col in row:

        if len(col.strip()) == 0:
            col_id +=1
            continue
            
        if is_number(col) or is_date(col):
            a = Atom(float(col))
            properties[col_id].add(r,a)
            atoms.add(a)
        else:
            e = Entity(col.strip())
            
            properties[col_id].add(r,e)
            entities.add(e)
        col_id += 1
 
    records.add(r)
    if last_row is not None:
        next_row.add(last_row,r)
    row_id += 1 
    last_row = r    


actions = [( ground_entity , t.nes ),
           ( ground_atom , t.nums ),
          ]

u = set()
b = set()

for action,data in actions:
    for datum in data:
        u.update(action(datum))

        
for p in properties:
    b.add(p)
    
u.add(records)
        


def transition(u,b,v_prods):
    
    u_actions = [( act_union , cross_product(u,u) ),
             ( act_intersection, cross_product(u,u) ),
             ( act_agg, u )
            ]

    bu_actions = [( act_join , cross_product(b,u) ),
                  ( act_sup, cross_product(u,b) )
                 ]

    b_actions = [ ( act_reverse, b),
                  ( act_chain, cross_product(b,b)) 
                ]


    print("Starting with " + str(len(u)) + " unaries")
    print("Starting with " + str(len(b)) + " binaries")
    
    u_next = set()
    b_next = set()
    
    for action,data in u_actions:
        for datum in data:
            for a in action(datum):
                u_next.add((datum,a))

    for action,data in bu_actions:
        for datum in data:
            for a in action(datum):
                u_next.add((datum,a))

    for action,data in b_actions:
        for datum in data:
            for a in action(datum):
                b_next.add((datum,a))

    print("Generated " + str(len(u_next)) + " unaries")
    print("Generated " + str(len(b_next)) + " binaries")    
    
    
    u_ret = set()
    b_ret = set()
    
    u_ret.update(u)
    b_ret.update(b)
    
    pruned = 0  
    
    for d,a in u_next:
        v = a.vals()
        

            
        if v is None:
            pruned += 1
            continue
        elif len(v) == 0:
            pruned += 1
            continue

        if Atom(2004.0) in v and len(v) == 1:
            v_prods.add(a)
            print("2004!")
            
        if hasattr(d,"__iter__"):
            if hasattr(v,"__iter__"):
                if set(d)==set(v):
                    pruned +=1
                    continue
        u_ret.add(a)
            
    print("Pruned "+ str(pruned) + " unaries")

    pruned = 0
    for d,a in b_next:
        v = a.vals()
            
        if v is None:
            pruned += 1
            continue
        elif len(v) == 0:
            pruned += 1
            continue
            
        if Atom(2004.0) in v and len(v) == 1:
            v_prods.add(a)
            print("2004!")
            
        if hasattr(d,"__iter__"):
            if hasattr(v,"__iter__"):
                if set(d)==set(v):
                    pruned +=1
                    continue

        b_ret.add(a)
    
    print("Pruned "+ str(pruned) + " binaries")
    return u_ret,b_ret,v_prods

class NonGenerator():
    def __eq__(self,other):
        return isinstance(other,NonGenerator)
    def __hash__(self):
        return "$$NG$$".__hash__()

class Chain():
    def __init__(self,a,b):
        self.a = a
        self.b = b

    def compile(self):
        a = self.a.compile()
        v = self.a.vals()

        b = self.b.compile()
        return lambda x,z: True in [a(x,y.v) and b(y.v,z) for y in v]

    def vals(self):
        avals = self.a.vals()
        bvals = self.b.vals()
        c = self.compile()

        ret = set()
        for a in avals:
            for b in bvals:
                if c(a.k,b.v):
                    ret.add(Pair(a.k,b.v))
        return ret

    def __str__(self):
        return "[CHAIN: "+str(self.a) +" x "+str(self.b)+"]"

    
class Join():
    def __init__(self, b, u):
        self.b = b
        self.u = u

    def compile(self):
        bc = self.b.compile()
        uc = self.u.compile()
        ys = self.u.vals()

        return lambda x: True in [uc(y) and bc(x, y) for y in ys]

    def vals(self):
        c = self.compile()
        ret = set()

        for x in self.b.vals():
            if c(x.k):
                ret.add(x.k)
        return ret

    def __str__(self):
        return("[JOIN: " + str(self.b) + " x " +str(self.u) + "]")
    
class CompJoin():
    def __init__(self, b, u):
        self.b = b
        self.u = u

    def compile(self):
        bc = self.b.compile()
        uc = self.u.compile()
        ys = self.u.vals()
           
        if NonGenerator() in ys:
            ys = [v.v for v in self.b.vals()]
        
        return lambda x: True in [uc(y) and bc(x, y) for y in ys]

    def vals(self):
        c = self.compile()
        ret = set()
        for x in self.b.vals():
            if c(x.k):
                ret.add(x.k)
        return ret

    def __str__(self):
        return("[JOIN: " + str(self.b) + " x " +str(self.u) + "]")

    

class GreaterThan():
    def __init__(self,a):
        self.a = a

    def __str__(self):
        return "[GT "+str(self.a)+"]"

    def compile(self):
        return lambda x: x.value>self.a.value

    def vals(self):
        return {NonGenerator()}

    

print(GreaterThan(Atom(100)).compile()(Atom(10)))
print(GreaterThan(Atom(100)).compile()(Atom(110)))


#print([str(a) for a in Join(properties[1],GreaterThan(Atom(1000))).vals()])

print([str(a) for a in CompJoin(Reverse(properties[1]), CompJoin(properties[1],GreaterThan(Atom(1000)))).vals()])

#print(Join(Reverse(properties[1]),list(records.vals())[0]).vals())
#print([str(a) for a in Join22(Reverse(properties[3]),records).vals()])
# Out:
# False
# True
# J
# J
# J
# ['[ATOM:1251.0]', '[ATOM:1542.0]', '[ATOM:12582.0]', '[ATOM:1032.0]', '[ATOM:4681.0]', '[ATOM:2951.0]', '[ATOM:1170.0]', '[ATOM:1907.0]', '[ATOM:1402.0]']
